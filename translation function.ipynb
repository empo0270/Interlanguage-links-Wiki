# %% [markdown]
# Import Libs

# %%
# Makes the plots appear within the notebook
# %matplotlib inline

# Two fundamental packages for doing data manipulation
import numpy as np                   # http://www.numpy.org/
import pandas as pd                  # http://pandas.pydata.org/

# Two related packages for plotting data
import matplotlib.pyplot as plt      # http://matplotlib.org/
import seaborn as sb                 # https://stanford.edu/~mwaskom/software/seaborn/

# Package for requesting data via the web and parsing resulting JSON
import requests
import json
from bs4 import BeautifulSoup

# Two packages for accessing the MySQL server
import pymysql                       # http://pymysql.readthedocs.io/en/latest/
import os                            # https://docs.python.org/3.4/library/os.html

# Packages for analyzing complex networks
import networkx as nx                # https://networkx.github.io/
import igraph as ig                  #If required manually in terminal use pip install python-igraph

# Setup the code environment to use plots with a white background and DataFrames show more columns and rows
sb.set_style('whitegrid')
pd.options.display.max_columns = 100
pd.options.display.max_rows = 110

# %%
page_title = "2013 Egyptian coup d'état"

# %%
def link_getter(page_title):
    
    _S="https://en.wikipedia.org/w/api.php?action=query&format=json&prop=langlinks&titles={0}&llprop=autonym|langname&lllimit=500".format(page_title)
    
    req = requests.get(_S)

    json_string = json.loads(req.text)
    
    _pageID=list(json_string['query']['pages'].keys())[0]

    _langlink_list=json_string['query']['pages'][_pageID]['langlinks']
    
    #_langAbrev_dict=dict()

    #for t in _langlink_list:
        #_lang=t['lang']
        #_langname=t['langname']
        #_langAbrev_dict[_lang]=_langname
    
    
    _langlink_dict=dict()

    for d in _langlink_list:
        _lang=d['lang']
        _title=d['*']
        _langlink_dict[_lang]=_title
        
    _langlink_dict['en'] = page_title
    
    return _langlink_dict

# %%
link_getter(page_title)

# %%
def name_getter(page_title):
    
    _S="https://en.wikipedia.org/w/api.php?action=query&format=json&prop=langlinks&titles={0}&llprop=autonym|langname&lllimit=500".format(page_title)
    
    req = requests.get(_S)

    json_string = json.loads(req.text)
    
    _pageID=list(json_string['query']['pages'].keys())[0]

    _langlink_list=json_string['query']['pages'][_pageID]['langlinks']
    
    _langname_dict=dict()

    for t in _langlink_list:
        _lang=t['lang']
        _langname=t['langname']
        _title=t['*']
        _langname_dict[_lang]=_langname
        
    _langname_dict['en'] = _title
    
    return _langname_dict

# %%
name_getter(page_title)
# Out:
# {'af': 'Afrikaans',
#  'ar': 'Arabic',
#  'arz': 'Egyptian Arabic',
#  'az': 'Azerbaijani',
#  'bg': 'Bulgarian',
#  'ca': 'Catalan',
#  'ckb': 'Central Kurdish',
#  'de': 'German',
#  'el': 'Greek',
#  'en': '2013年埃及政变',
#  'es': 'Spanish',
#  'fa': 'Persian',
#  'fi': 'Finnish',
#  'fr': 'French',
#  'he': 'Hebrew',
#  'hi': 'Hindi',
#  'id': 'Indonesian',
#  'it': 'Italian',
#  'ja': 'Japanese',
#  'ko': 'Korean',
#  'nl': 'Dutch',
#  'pl': 'Polish',
#  'pt': 'Portuguese',
#  'ro': 'Romanian',
#  'ru': 'Russian',
#  'sr': 'Serbian',
#  'tg': 'Tajik',
#  'tr': 'Turkish',
#  'uk': 'Ukrainian',
#  'ur': 'Urdu',
#  'vi': 'Vietnamese',
#  'zh': 'Chinese'}

# %%
_langAbrev_dict = {}

names_and_langs = name_getter(page_title)

for lang,langname in names_and_langs.items():
    _langAbrev_dict[lang] = langname

# %%
titles_and_lang_dict = {}

pages_and_langs = link_getter(page_title)

for lang,title in pages_and_langs.items():
    titles_and_lang_dict[lang] = title

# %%
def get_page_outlinks(page_title,lang='en',redirects=1):
    # Replace spaces with underscores
    page_title = page_title.replace(' ','_')
    
    bad_titles = ['Special:','Wikipedia:','Help:','Template:','Category:','International Standard','Portal:','s:','File:']
    
    # Get the response from the API for a query
    # After passing a page title, the API returns the HTML markup of the current article version within a JSON payload
    req = requests.get('https://{2}.wikipedia.org/w/api.php?action=parse&format=json&page={0}&redirects={1}&prop=text&disableeditsection=1&disabletoc=1'.format(page_title,redirects,lang))
    
    # Read the response into JSON to parse and extract the HTML
    json_string = json.loads(req.text)
    
    # Initialize an empty list to store the links
    outlinks_list = [] 
    
    if 'parse' in json_string.keys():
        page_html = json_string['parse']['text']['*']

        # Parse the HTML into Beautiful Soup
        soup = BeautifulSoup(page_html,'lxml')

        # Delete tags associated with templates
        for tag in soup.find_all('tr'):
            tag.replace_with('')

        # For each paragraph tag, extract the titles within the links
        for para in soup.find_all('p'):
            for link in para.find_all('a'):
                if link.has_attr('title'):
                    title = link['title']
                    # Ignore links that aren't interesting
                    if all(bad not in title for bad in bad_titles):
                        outlinks_list.append(title)

        # For each unordered list, extract the titles within the child links
        for unordered_list in soup.find_all('ul'):
            for item in unordered_list.find_all('li'):
                for link in item.find_all('a'):
                    if link.has_attr('title'):
                        title = link['title']
                        # Ignore links that aren't interesting
                        if all(bad not in title for bad in bad_titles):
                            outlinks_list.append(title)

    return outlinks_list

# %%
outlinks_per_lang = {}

language_titles = link_getter(page_title)

for lang,title in language_titles.items():
    #print("The language is",lang,"and the article title is", title)
    outlinks_per_lang[lang] = get_page_outlinks(title,lang)

# %%
def get_outlink_translations(outlinks_per_lang):
    translation_dict = dict()
    for lang,links in outlinks_per_lang.items():
        _page_titles = list(set(links))

        translation_dict[lang] = {}

        for _page_title in _page_titles:
            _S="https://{1}.wikipedia.org/w/api.php?action=query&format=json&prop=langlinks&titles={0}&redirects=1&lllimit=500&formatversion=2".format(_page_title,lang)
            response = requests.get(_S).json()
            if 'pages' in response['query'].keys():
                langlink_dict = response['query']['pages'][0]
                translation_dict[lang][_page_title] = {}
                if 'langlinks' in langlink_dict.keys():
                    for _ll in langlink_dict['langlinks']:
                        _ll_title = _ll['title']
                        _ll_lang = _ll['lang']
                        translation_dict[lang][_page_title][_ll_lang] = _ll_title
            else:
                translation_dict[lang][_page_title] = {}
                
    return translation_dict

# %%
translation_dict = get_outlink_translations(outlinks_per_lang)

# %%
list(translation_dict.items())[0]
# Out:
# ('he',
#  {'1 ביולי': {'ab': 'Ҧхынгәы 1',
#    'af': '1 Julie',
#    'als': '1. Juli',
#    'am': '1 July',
#    'an': '1 de chulio',
#    'ang': '1. Mǣdmōnðes',
#    'ar': '1 يوليو',
#    'arz': '1 يوليه',
#    'as': '১ জুলাই',
#    'ast': '1 de xunetu',
#    'av': '1 Июл',
#    'az': '1 iyul',
#    'ba': '1 июль',
#    'bat-smg': 'Lėipas 1',
#    'bcl': 'Hulyo 1',
#    'be': '1 ліпеня',
#    'be-x-old': '1 ліпеня',
#    'bg': '1 юли',
#    'bh': '१ जुलाई',
#    'bn': '১ জুলাই',
#    'bpy': 'জুলাই ১',
#    'br': '1añ Gouere',
#    'bs': '1. juli',
#    'ca': '1 de juliol',
#    'cdo': '7 nguŏk 1 hô̤',
#    'ce': '1 июль',
#    'ceb': 'Hulyo 1',
#    'ckb': '١ی تەممووز',
#    'co': '1 di lugliu',
#    'cs': '1. červenec',
#    'csb': '1 lëpińca',
#    'cv': 'Утă, 1',
#    'cy': '1 Gorffennaf',
#    'da': '1. juli',
#    'de': '1. Juli',
#    'diq': '1 Temuz',
#    'dv': 'ޖުލައި 1',
#    'ee': 'Siamlɔm 1',
#    'el': '1 Ιουλίου',
#    'eml': '1 ed lói',
#    'en': 'July 1',
#    'eo': '1-a de julio',
#    'es': '1 de julio',
#    'et': '1. juuli',
#    'eu': 'Uztailaren 1',
#    'ext': '1 júliu',
#    'fa': '۱ ژوئیه',
#    'fi': '1. heinäkuuta',
#    'fiu-vro': '1. hainakuu päiv',
#    'fo': '1. juli',
#    'fr': '1er juillet',
#    'frp': '1ér j·ulyèt',
#    'fur': '1 di Lui',
#    'fy': '1 july',
#    'ga': '1 Iúil',
#    'gag': '1 Orak ay',
#    'gan': '7月1號',
#    'gd': '1 an t-Iuchar',
#    'gl': '1 de xullo',
#    'gu': 'જુલાઇ ૧',
#    'gv': '1 Jerrey Souree',
#    'hak': '7-ngie̍t 1-ngit',
#    'hi': '१ जुलाई',
#    'hif': '1 July',
#    'hr': '1. srpnja',
#    'hsb': '1. julija',
#    'ht': '1e jiyè',
#    'hu': 'Július 1.',
#    'hy': 'Հուլիսի 1',
#    'ia': '1 de julio',
#    'id': '1 Juli',
#    'ie': '1 juli',
#    'ig': '1 Julaị',
#    'ilo': 'Hulio 1',
#    'io': '1 di julio',
#    'is': '1. júlí',
#    'it': '1º luglio',
#    'ja': '7月1日',
#    'jbo': "zelma'i 1moi",
#    'jv': '1 Juli',
#    'ka': '1 ივლისი',
#    'kk': '1 шілде',
#    'kl': 'Juuli 1',
#    'kn': 'ಜುಲೈ ೧',
#    'ko': '7월 1일',
#    'krc': '1 июль',
#    'ksh': '1. Juuli',
#    'ku': "1'ê tîrmehê",
#    'kv': '1 сора',
#    'ky': '1 июль',
#    'la': '1 Iulii',
#    'lb': '1. Juli',
#    'li': '1 juli',
#    'lmo': '01 07',
#    'lt': 'Liepos 1',
#    'lv': '1. jūlijs',
#    'mai': '१ जुलाई',
#    'mg': '1 Jolay',
#    'mhr': '1 Сӱрем',
#    'mk': '1 јули',
#    'ml': 'ജൂലൈ 1',
#    'mn': '7 сарын 1',
#    'mr': '१ जुलै',
#    'ms': '1 Julai',
#    'my': '၁ ဇူလိုင်',
#    'myv': 'Медьковонь 1 чи',
#    'nah': '1 Tlachicōnti',
#    'nap': "1 'e luglio",
#    'nds': '1. Juli',
#    'nds-nl': '1 juli',
#    'ne': '१ जुलाई',
#    'new': 'जुलाई १',
#    'nl': '1 juli',
#    'nn': '1. juli',
#    'no': '1. juli',
#    'nov': '1 de julie',
#    'nrm': '1 Juilet',
#    'nso': 'Mosegamanye 1',
#    'oc': '1èr de julhet',
#    'olo': '1. heinykuudu',
#    'or': '୧ ଜୁଲାଇ',
#    'os': '1 июлы',
#    'pa': '1 ਜੁਲਾਈ',
#    'pag': 'July 1',
#    'pam': 'Juliu 1',
#    'pl': '1 lipca',
#    'pnb': '1 جولائی',
#    'pt': '1 de julho',
#    'qu': '1 ñiqin anta situwa killapi',
#    'ro': '1 iulie',
#    'ru': '1 июля',
#    'rue': '1. юл',
#    'sa': '१ जुलाई',
#    'sah': 'От ыйын 1',
#    'scn': 'Primu di giugnettu',
#    'sco': '1 Julie',
#    'se': 'Suoidnemánu 1.',
#    'sh': '1. 7.',
#    'simple': 'July 1',
#    'sk': '1. júl',
#    'sl': '1. julij',
#    'sq': '1 Korrik',
#    'sr': '1. јул',
#    'su': '1 Juli',
#    'sv': '1 juli',
#    'sw': '1 Julai',
#    'szl': '1 lipca',
#    'ta': 'ஜூலை 1',
#    'te': 'జూలై 1',
#    'tg': '1 июл',
#    'th': '1 กรกฎาคม',
#    'tk': '1 iýul',
#    'tl': 'Hulyo 1',
#    'tr': '1 Temmuz',
#    'tt': '1 июль',
#    'uk': '1 липня',
#    'ur': '1 جولائی',
#    'uz': '1-iyul',
#    'vec': '1° de lujo',
#    'vi': '1 tháng 7',
#    'vls': '1 juli',
#    'vo': 'Yulul 1',
#    'wa': "1î d' djulete",
#    'war': 'Hulyo 1',
#    'xal': 'Така сарин 1',
#    'xmf': '1 კვირკვე',
#    'yi': '1טן יולי',
#    'yo': '1 July',
#    'zea': '1 juli',
#    'zh': '7月1日',
#    'zh-min-nan': '7 goe̍h 1 ji̍t',
#    'zh-yue': '7月1號'},
#   '2012': {'ab': '2012',
#    'af': '2012',
#    'als': '2012',
#    'am': '2012 እ.ኤ.አ.',
#    'an': '2012',
#    'ar': '2012',
#    'arc': '2012',
#    'arz': '2012',
#    'as': '২০১২',
#    'ast': '2012',
#    'av': '2012 сон',
#    'ay': '2012',
#    'az': '2012',
#    'azb': '۲۰۱۲ (میلادی)',
#    'ba': '2012 йыл',
#    'bar': '2012',
#    'bat-smg': '2012',
#    'bcl': '2012',
#    'be': '2012',
#    'be-x-old': '2012',
#    'bg': '2012',
#    'bh': '२०१२',
#    'bjn': '2012',
#    'bn': '২০১২',
#    'br': '2012',
#    'bs': '2012.',
#    'bxr': '2012 он',
#    'ca': '2012',
#    'cdo': '2012 nièng',
#    'ce': '2012 шо',
#    'ceb': '2012',
#    'ckb': '٢٠١٢',
#    'co': '2012',
#    'crh': '2012',
#    'cs': '2012',
#    'csb': '2012',
#    'cv': '2012',
#    'cy': '2012',
#    'da': '2012',
#    'de': '2012',
#    'diq': '2012',
#    'dsb': '2012',
#    'dv': '2012',
#    'el': '2012',
#    'eml': '2012',
#    'en': '2012',
#    'eo': '2012',
#    'es': '2012',
#    'et': '2012',
#    'eu': '2012',
#    'ext': '2012',
#    'fa': '۲۰۱۲ (میلادی)',
#    'fi': '2012',
#    'fiu-vro': '2012',
#    'fo': '2012',
#    'fr': '2012',
#    'frp': '2012',
#    'frr': '2012',
#    'fur': '2012',
#    'fy': '2012',
#    'ga': '2012',
#    'gag': '2012',
#    'gan': '2012年',
#    'gd': '2012',
#    'gl': '2012',
#    'glk': '۲۰۱۲',
#    'gn': '2012',
#    'gv': '2012',
#    'hak': '2012-ngièn',
#    'hi': '२०१२',
#    'hif': '2012',
#    'hr': '2012.',
#    'hsb': '2012',
#    'ht': '2012 (almanak gregoryen)',
#    'hu': '2012',
#    'hy': '2012',
#    'ia': '2012',
#    'id': '2012',
#    'ilo': '2012',
#    'io': '2012',
#    'is': '2012',
#    'it': '2012',
#    'ja': '2012年',
#    'jbo': '2012moi',
#    'jv': '2012',
#    'ka': '2012',
#    'kab': '2012',
#    'kk': '2012 жыл',
#    'kl': '2012',
#    'kn': '೨೦೧೨',
#    'ko': '2012년',
#    'koi': '2012’ во',
#    'krc': '2012 джыл',
#    'ksh': 'Joohr 2012',
#    'ku': '2012',
#    'kv': '2012 во',
#    'kw': '2012',
#    'ky': '2012',
#    'la': '2012',
#    'lb': '2012',
#    'lez': '2012 йис',
#    'li': '2012',
#    'lij': '2012',
#    'lmo': '2012',
#    'lo': 'ຄ.ສ. 2012',
#    'lrc': '۲۰۱۲ (زایئشتی)',
#    'lt': '2012 m.',
#    'lv': '2012. gads',
#    'mai': '२०१२',
#    'map-bms': '2012',
#    'mhr': '2012',
#    'mi': '2012',
#    'min': '2012',
#    'mk': '2012',
#    'ml': '2012',
#    'mn': '2012 он',
#    'mr': 'इ.स. २०१२',
#    'mrj': '2012 и',
#    'ms': '2012',
#    'my': '၂၀၁၂',
#    'myv': '2012 ие',
#    'mzn': '۲۰۱۲ (میلادی)',
#    'na': '2012',
#    'nah': '2012',
#    'nap': '2012',
#    'nds': '2012',
#    'nds-nl': '2012',
#    'ne': 'सन २०१२',
#    'new': 'सन् २०१२',
#    'nl': '2012',
#    'nn': '2012',
#    'no': '2012',
#    'nrm': '2012',
#    'nso': '2012',
#    'oc': '2012',
#    'olo': '2012',
#    'or': '୨୦୧୨',
#    'os': '2012-æм аз',
#    'pa': '2012',
#    'pag': '2012',
#    'pap': '2012',
#    'pi': '२०१२',
#    'pl': '2012',
#    'pms': '2012',
#    'pnb': '2012',
#    'ps': '2012',
#    'pt': '2012',
#    'qu': '2012',
#    'ro': '2012',
#    'ru': '2012 год',
#    'rue': '2012',
#    'sa': '२०१२',
#    'sah': '2012 сыл',
#    'sc': '2012',
#    'scn': '2012',
#    'sco': '2012',
#    'sd': '2012ع',
#    'se': '2012',
#    'sh': '2012',
#    'si': '2012',
#    'simple': '2012',
#    'sk': '2012',
#    'sl': '2012',
#    'so': '2012',
#    'sq': '2012',
#    'sr': '2012',
#    'stq': '2012',
#    'sv': '2012',
#    'sw': '2012',
#    'szl': '2012',
#    'ta': '2012',
#    'te': '2012',
#    'tet': '2012',
#    'tg': 'Соли 2012',
#    'th': 'พ.ศ. 2555',
#    'tk': '2012',
#    'tl': '2012',
#    'tr': '2012',
#    'tt': '2012 ел',
#    'tw': '2012',
#    'tyv': '2012 чыл',
#    'udm': '2012 ар',
#    'uk': '2012',
#    'ur': '2012ء',
#    'uz': '2012',
#    'vec': '2012',
#    'vi': '2012',
#    'vls': '2012',
#    'vo': '2012',
#    'wa': '2012',
#    'war': '2012',
#    'xal': '2012 җил',
#    'xmf': '2012',
#    'yi': '2012',
#    'yo': '2012',
#    'zea': '2012',
#    'zh': '2012年',
#    'zh-classical': '二〇一二年',
#    'zh-min-nan': '2012 nî',
#    'zh-yue': '2012年',
#    'zu': '2012'},
#   '2013': {'ab': '2013',
#    'af': '2013',
#    'als': '2013',
#    'am': '2013 እ.ኤ.አ.',
#    'an': '2013',
#    'ar': '2013',
#    'arz': '2013',
#    'ast': '2013',
#    'av': '2013 сон',
#    'ay': '2013',
#    'az': '2013',
#    'azb': '۲۰۱۳ (میلادی)',
#    'ba': '2013 йыл',
#    'bar': '2013',
#    'bat-smg': '2013',
#    'bcl': '2013',
#    'be': '2013',
#    'be-x-old': '2013',
#    'bg': '2013',
#    'bh': '२०१३',
#    'bjn': '2013',
#    'bn': '২০১৩',
#    'br': '2013',
#    'bs': '2013.',
#    'bxr': '2013 он',
#    'ca': '2013',
#    'cdo': '2013 nièng',
#    'ce': '2013 шо',
#    'ceb': '2013',
#    'ckb': '٢٠١٣',
#    'co': '2013',
#    'crh': '2013',
#    'cs': '2013',
#    'csb': '2013',
#    'cv': '2012 ҫул',
#    'cy': '2013',
#    'da': '2013',
#    'de': '2013',
#    'diq': '2013',
#    'dsb': '2013',
#    'dv': '2013',
#    'dz': '༢༠༡༣',
#    'el': '2013',
#    'eml': '2013',
#    'en': '2013',
#    'eo': '2013',
#    'es': '2013',
#    'et': '2013',
#    'eu': '2013',
#    'ext': '2013',
#    'fa': '۲۰۱۳ (میلادی)',
#    'fi': '2013',
#    'fiu-vro': '2013',
#    'fo': '2013',
#    'fr': '2013',
#    'frp': '2013',
#    'frr': '2013',
#    'fur': '2013',
#    'fy': '2013',
#    'ga': '2013',
#    'gag': '2013',
#    'gan': '2013年',
#    'gd': '2013',
#    'gl': '2013',
#    'gn': '2013',
#    'gv': '2013',
#    'hak': '2013-ngièn',
#    'hi': '२०१३',
#    'hif': '2013',
#    'hr': '2013.',
#    'hsb': '2013',
#    'hu': '2013',
#    'hy': '2013',
#    'ia': '2013',
#    'id': '2013',
#    'ilo': '2013',
#    'io': '2013',
#    'is': '2013',
#    'it': '2013',
#    'ja': '2013年',
#    'jbo': '2013moi',
#    'jv': '2013',
#    'ka': '2013',
#    'kaa': '2013',
#    'kab': '2013',
#    'kk': '2013 жыл',
#    'kn': '೨೦೧೩',
#    'ko': '2013년',
#    'krc': '2013 джыл',
#    'ksh': 'Joohr 2013',
#    'ku': '2013',
#    'kv': '2013 во',
#    'kw': '2013',
#    'ky': '2013',
#    'la': '2013',
#    'lb': '2013',
#    'lez': '2013 йис',
#    'li': '2013',
#    'lij': '2013',
#    'lmo': '2013',
#    'lt': '2013 m.',
#    'lv': '2013. gads',
#    'mai': '२०१३',
#    'map-bms': '2013',
#    'mhr': '2013',
#    'mi': '2013',
#    'min': '2013',
#    'mk': '2013',
#    'ml': '2013',
#    'mn': '2013 он',
#    'mr': 'इ.स. २०१३',
#    'mrj': '2013 и',
#    'ms': '2013',
#    'my': '၂၀၁၃',
#    'myv': '2013 ие',
#    'mzn': '۲۰۱۳ (میلادی)',
#    'na': '2013',
#    'nah': '2013',
#    'nap': '2013',
#    'nds': '2013',
#    'nds-nl': '2013',
#    'ne': 'सन २०१३',
#    'new': 'सन् २०१३',
#    'nl': '2013',
#    'nn': '2013',
#    'no': '2013',
#    'nrm': '2013',
#    'nso': '2013',
#    'oc': '2013',
#    'olo': '2013',
#    'or': '୨୦୧୩',
#    'os': '2013-æм аз',
#    'pa': '2013',
#    'pag': '2013',
#    'pap': '2013',
#    'pi': '२०१३',
#    'pl': '2013',
#    'pms': '2013',
#    'pnb': '2013',
#    'ps': '2013',
#    'pt': '2013',
#    'qu': '2013',
#    'ro': '2013',
#    'ru': '2013 год',
#    'rue': '2013',
#    'sah': '2013 сыл',
#    'sc': '2013',
#    'scn': '2013',
#    'sco': '2013',
#    'sd': '2013ع',
#    'se': '2013',
#    'sh': '2013',
#    'si': '2013',
#    'simple': '2013',
#    'sk': '2013',
#    'sl': '2013',
#    'so': '2013',
#    'sq': '2013',
#    'sr': '2013',
#    'stq': '2013',
#    'sv': '2013',
#    'sw': '2013',
#    'szl': '2013',
#    'ta': '2013',
#    'te': '2013',
#    'tg': 'Соли 2013',
#    'th': 'พ.ศ. 2556',
#    'tk': '2013',
#    'tl': '2013',
#    'tr': '2013',
#    'tt': '2013 ел',
#    'tw': '2013',
#    'tyv': '2013 чыл',
#    'udm': '2013 ар',
#    'uk': '2013',
#    'ur': '2013ء',
#    'uz': '2013',
#    'vec': '2013',
#    'vi': '2013',
#    'vls': '2013',
#    'vo': '2013',
#    'wa': '2013',
#    'war': '2013',
#    'xmf': '2013',
#    'yi': '2013',
#    'yo': '2013',
#    'zea': '2013',
#    'zh': '2013年',
#    'zh-classical': '二〇一三年',
#    'zh-min-nan': '2013 nî',
#    'zh-yue': '2013年',
#    'zu': '2013'},
#   '2014': {'ab': '2014',
#    'af': '2014',
#    'als': '2014',
#    'am': '2014 እ.ኤ.አ.',
#    'an': '2014',
#    'ar': '2014',
#    'arz': '2014',
#    'ast': '2014',
#    'av': '2014 сон',
#    'az': '2014',
#    'azb': '۲۰۱۴ (میلادی)',
#    'ba': '2014 йыл',
#    'bar': '2014',
#    'bat-smg': '2014',
#    'bcl': '2014',
#    'be': '2014',
#    'be-x-old': '2014',
#    'bg': '2014',
#    'bh': '२०१४',
#    'bn': '২০১৪',
#    'br': '2014',
#    'bs': '2014.',
#    'bxr': '2014 он',
#    'ca': '2014',
#    'cdo': '2014 nièng',
#    'ce': '2014 шо',
#    'ceb': '2014',
#    'ckb': '٢٠١٤',
#    'crh': '2014',
#    'cs': '2014',
#    'csb': '2014',
#    'cy': '2014',
#    'da': '2014',
#    'de': '2014',
#    'diq': '2014',
#    'dsb': '2014',
#    'dz': '༢༠༡༤',
#    'el': '2014',
#    'eml': '2014',
#    'en': '2014',
#    'eo': '2014',
#    'es': '2014',
#    'et': '2014',
#    'eu': '2014',
#    'ext': '2014',
#    'fa': '۲۰۱۴ (میلادی)',
#    'fi': '2014',
#    'fiu-vro': '2014',
#    'fo': '2014',
#    'fr': '2014',
#    'frp': '2014',
#    'frr': '2014',
#    'fur': '2014',
#    'fy': '2014',
#    'ga': '2014',
#    'gan': '2014年',
#    'gd': '2014',
#    'gl': '2014',
#    'gn': '2014',
#    'gv': '2014',
#    'hak': '2014-ngièn',
#    'hi': '२०१४',
#    'hif': '2014',
#    'hr': '2014.',
#    'hsb': '2014',
#    'hu': '2014',
#    'hy': '2014',
#    'ia': '2014',
#    'id': '2014',
#    'ilo': '2014',
#    'io': '2014',
#    'is': '2014',
#    'it': '2014',
#    'ja': '2014年',
#    'jbo': '2014moi',
#    'jv': '2014',
#    'ka': '2014',
#    'kab': '2014',
#    'kk': '2014 жыл',
#    'kn': '೨೦೧೪',
#    'ko': '2014년',
#    'krc': '2014 джыл',
#    'ku': '2014',
#    'kv': '2014 во',
#    'kw': '2014',
#    'ky': '2014',
#    'la': '2014',
#    'lb': '2014',
#    'lez': '2014 йис',
#    'li': '2014',
#    'lij': '2014',
#    'lmo': '2014',
#    'lrc': '2014',
#    'lt': '2014 m.',
#    'lv': '2014. gads',
#    'mai': '२०१४',
#    'map-bms': '2014',
#    'mhr': '2014',
#    'mi': '2014',
#    'min': '2014',
#    'mk': '2014',
#    'ml': '2014',
#    'mn': '2014 он',
#    'mr': 'इ.स. २०१४',
#    'mrj': '2014 и',
#    'ms': '2014',
#    'mt': '2014',
#    'my': '၂၀၁၄',
#    'myv': '2014 ие',
#    'mzn': '۲۰۱۴ (میلادی)',
#    'na': '2014',
#    'nah': '2014',
#    'nap': '2014',
#    'nds': '2014',
#    'nds-nl': '2014',
#    'ne': 'सन् २०१४',
#    'new': 'सन् २०१४',
#    'nl': '2014',
#    'nn': '2014',
#    'no': '2014',
#    'nrm': '2014',
#    'nso': '2014',
#    'oc': '2014',
#    'olo': '2014',
#    'or': '୨୦୧୪',
#    'os': '2014-æм аз',
#    'pa': '2014',
#    'pap': '2014',
#    'pi': '२०१४',
#    'pl': '2014',
#    'pms': '2014',
#    'pnb': '2014',
#    'pt': '2014',
#    'qu': '2014',
#    'ro': '2014',
#    'roa-rup': '2014',
#    'ru': '2014 год',
#    'rue': '2014',
#    'sah': '2014 сыл',
#    'sc': '2014',
#    'scn': '2014',
#    'sco': '2014',
#    'sd': '2014ع',
#    'se': '2014',
#    'sh': '2014',
#    'si': '2014',
#    'simple': '2014',
#    'sk': '2014',
#    'sl': '2014',
#    'so': '2014',
#    'sq': '2014',
#    'sr': '2014',
#    'stq': '2014',
#    'su': '2014',
#    'sv': '2014',
#    'sw': '2014',
#    'szl': '2014',
#    'ta': '2014',
#    'tg': 'Соли 2014',
#    'th': 'พ.ศ. 2557',
#    'tk': '2014',
#    'tl': '2014',
#    'tr': '2014',
#    'tt': '2014 ел',
#    'tw': '2014',
#    'tyv': '2014 чыл',
#    'udm': '2014 ар',
#    'uk': '2014',
#    'ur': '2014ء',
#    'uz': '2014',
#    'vec': '2014',
#    'vi': '2014',
#    'vls': '2014',
#    'vo': '2014',
#    'wa': '2014',
#    'war': '2014',
#    'xmf': '2014',
#    'yi': '2014',
#    'yo': '2014',
#    'zea': '2014',
#    'zh': '2014年',
#    'zh-classical': '二〇一四年',
#    'zh-min-nan': '2014 nî',
#    'zh-yue': '2014年',
#    'zu': '2014'},
#   '22 בנובמבר': {'af': '22 November',
#    'als': '22. November',
#    'am': '22 November',
#    'an': '22 de noviembre',
#    'ar': '22 نوفمبر',
#    'arz': '22 نوفمبر',
#    'ast': '22 de payares',
#    'av': '22 Ноябр',
#    'az': '22 noyabr',
#    'azb': '۲۲ نوْوامبر',
#    'ba': '22 ноябрь',
#    'bat-smg': 'Lapkristė 22',
#    'bcl': 'Nobyembre 22',
#    'be': '22 лістапада',
#    'be-x-old': '22 лістапада',
#    'bg': '22 ноември',
#    'bh': '२२ नवंबर',
#    'bjn': '22 Nupimbir',
#    'bn': '২২ নভেম্বর',
#    'bpy': 'নভেম্বর ২২',
#    'br': '22 Du',
#    'bs': '22. novembar',
#    'ca': '22 de novembre',
#    'cdo': '11 nguŏk 22 hô̤',
#    'ce': '22 ноябрь',
#    'ceb': 'Nobiyembre 22',
#    'ckb': '٢٢ی تشرینی دووەم',
#    'co': '22 nuvembri',
#    'cs': '22. listopad',
#    'csb': '22 lëstopadnika',
#    'cv': 'Чӳк, 22',
#    'cy': '22 Tachwedd',
#    'da': '22. november',
#    'de': '22. November',
#    'diq': '22 Tışrino Peyên',
#    'dv': 'ނޮވެމްބަރު 22',
#    'el': '22 Νοεμβρίου',
#    'en': 'November 22',
#    'eo': '22-a de novembro',
#    'es': '22 de noviembre',
#    'et': '22. november',
#    'eu': 'Azaroaren 22',
#    'ext': '22 noviembri',
#    'fa': '۲۲ نوامبر',
#    'fi': '22. marraskuuta',
#    'fiu-vro': '22. märtekuu päiv',
#    'fo': '22. november',
#    'fr': '22 novembre',
#    'frp': '22 novembro',
#    'fur': '22 di Novembar',
#    'fy': '22 novimber',
#    'ga': '22 Samhain',
#    'gag': '22 Kasım ay',
#    'gan': '11月22號',
#    'gd': '22 an t-Samhain',
#    'gl': '22 de novembro',
#    'gu': 'નવેમ્બર ૨૨',
#    'gv': '22 Mee Houney',
#    'hak': '11-ngie̍t 22-ngit',
#    'hi': '२२ नवम्बर',
#    'hif': '22 November',
#    'hr': '22. studenog',
#    'hsb': '22. nowembra',
#    'ht': '22 novanm',
#    'hu': 'November 22.',
#    'hy': 'Նոյեմբերի 22',
#    'ia': '22 de novembre',
#    'id': '22 November',
#    'ilo': 'Nobiembre 22',
#    'io': '22 di novembro',
#    'is': '22. nóvember',
#    'it': '22 novembre',
#    'ja': '11月22日',
#    'jv': '22 November',
#    'ka': '22 ნოემბერი',
#    'kab': '22 wamber',
#    'kk': '22 қараша',
#    'kl': 'Novemberi 22',
#    'kn': 'ನವೆಂಬರ್ ೨೨',
#    'ko': '11월 22일',
#    'krc': '22 ноябрь',
#    'ksh': '22. Novemmber',
#    'ku': "22'ê sermawezê",
#    'kv': '22 вӧльгым',
#    'ky': '22-ноябрь',
#    'la': '22 Novembris',
#    'lb': '22. November',
#    'lez': '22 ноябрь',
#    'li': '22 november',
#    'lmo': '22 11',
#    'lt': 'Lapkričio 22',
#    'lv': '22. novembris',
#    'mai': '२२ नवम्बर',
#    'mg': '22 Novambra',
#    'mhr': '22 Кылме',
#    'mk': '22 ноември',
#    'ml': 'നവംബർ 22',
#    'mn': '11 сарын 22',
#    'mr': 'नोव्हेंबर २२',
#    'ms': '22 November',
#    'mt': "22 ta' Novembru",
#    'my': '၂၂ နိုဝင်ဘာ',
#    'myv': 'Сундерьковонь 22 чи',
#    'nah': 'Tlamahtlāccēti 22',
#    'nap': "22 'e nuvembre",
#    'nds': '22. November',
#    'nds-nl': '22 november',
#    'ne': '२२ नोभेम्बर',
#    'new': 'नोभेम्बर २२',
#    'nl': '22 november',
#    'nn': '22. november',
#    'no': '22. november',
#    'nrm': '22 Novembre',
#    'nso': 'Dibatsela 22',
#    'oc': '22 de novembre',
#    'or': '୨୨ ନଭେମ୍ବର',
#    'pa': '22 ਨਵੰਬਰ',
#    'pag': 'November 22',
#    'pam': 'Nobiembri 22',
#    'pl': '22 listopada',
#    'pnb': '22 نومبر',
#    'pt': '22 de novembro',
#    'qu': "22 ñiqin ayamarq'a killapi",
#    'ro': '22 noiembrie',
#    'ru': '22 ноября',
#    'rue': '22. новембер',
#    'sa': '२२ नवम्बर',
#    'sah': 'Сэтинньи 22',
#    'scn': '22 di nuvèmmiru',
#    'sco': '22 November',
#    'sd': '22 نومبر',
#    'se': 'Skábmamánu 22.',
#    'sh': '22. 11.',
#    'simple': 'November 22',
#    'sk': '22. november',
#    'sl': '22. november',
#    'sq': '22 Nëntor',
#    'sr': '22. новембар',
#    'stq': '22. November',
#    'su': '22 Nopémber',
#    'sv': '22 november',
#    'sw': '22 Novemba',
#    'ta': 'நவம்பர் 22',
#    'te': 'నవంబర్ 22',
#    'tg': '22 ноябр',
#    'th': '22 พฤศจิกายน',
#    'tk': '22 noýabr',
#    'tl': 'Nobyembre 22',
#    'tr': '22 Kasım',
#    'tt': '22 ноябрь',
#    'tyv': '22 Он бир ай',
#    'uk': '22 листопада',
#    'ur': '22 نومبر',
#    'uz': '22-noyabr',
#    'vec': '22 de novenbre',
#    'vi': '22 tháng 11',
#    'vls': '22 november',
#    'vo': 'Novul 22',
#    'wa': "22 d' nôvimbe",
#    'war': 'Nobyembre 22',
#    'xal': 'Үкр сарин 22',
#    'xmf': '22 გერგობათუთა',
#    'yi': '22סטן נאוועמבער',
#    'yo': '22 November',
#    'zea': '22 november',
#    'zh': '11月22日',
#    'zh-min-nan': '11 goe̍h 22 ji̍t',
#    'zh-yue': '11月22號'},
#   '29 ביוני': {'ab': 'Рашәара 29',
#    'af': '29 Junie',
#    'als': '29. Juni',
#    'am': '29 June',
#    'an': '29 de chunio',
#    'ar': '29 يونيو',
#    'arz': '29 يونيه',
#    'ast': '29 de xunu',
#    'av': '29 Июн',
#    'az': '29 iyun',
#    'ba': '29 июнь',
#    'bat-smg': 'Bėrželė 29',
#    'bcl': 'Hunyo 29',
#    'be': '29 чэрвеня',
#    'be-x-old': '29 чэрвеня',
#    'bg': '29 юни',
#    'bh': '२९ जून',
#    'bn': '২৯ জুন',
#    'bpy': 'জুন ২৯',
#    'br': '29 Mezheven',
#    'bs': '29. juni',
#    'ca': '29 de juny',
#    'cdo': '6 nguŏk 29 hô̤',
#    'ce': '29 июнь',
#    'ceb': 'Hunyo 29',
#    'ckb': '٢٩ی حوزەیران',
#    'co': '29 di ghjugnu',
#    'cs': '29. červen',
#    'csb': '29 czerwińca',
#    'cv': 'Çĕртме, 29',
#    'cy': '29 Mehefin',
#    'da': '29. juni',
#    'de': '29. Juni',
#    'diq': '29 Heziran',
#    'dsb': '29. junija',
#    'dv': 'ޖޫން 29',
#    'el': '29 Ιουνίου',
#    'eml': '29 ed zógn',
#    'en': 'June 29',
#    'eo': '29-a de junio',
#    'es': '29 de junio',
#    'et': '29. juuni',
#    'eu': 'Ekainaren 29',
#    'ext': '29 juñu',
#    'fa': '۲۹ ژوئن',
#    'fi': '29. kesäkuuta',
#    'fiu-vro': '29. piimäkuu päiv',
#    'fo': '29. juni',
#    'fr': '29 juin',
#    'frp': '29 jouen',
#    'fur': '29 di Jugn',
#    'fy': '29 juny',
#    'ga': '29 Meitheamh',
#    'gag': '29 Kirez ay',
#    'gan': '6月29號',
#    'gd': '29 an t-Ògmhios',
#    'gl': '29 de xuño',
#    'gu': 'જૂન ૨૯',
#    'gv': '29 Mean Souree',
#    'hak': '6-ngie̍t 29-ngit',
#    'hi': '२९ जून',
#    'hif': '29 June',
#    'hr': '29. lipnja',
#    'hsb': '29. junija',
#    'ht': '29 jen',
#    'hu': 'Június 29.',
#    'hy': 'Հունիսի 29',
#    'ia': '29 de junio',
#    'id': '29 Juni',
#    'ie': '29 junio',
#    'ig': 'Önwa ishií 29',
#    'ilo': 'Hunio 29',
#    'io': '29 di junio',
#    'is': '29. júní',
#    'it': '29 giugno',
#    'ja': '6月29日',
#    'jbo': "xavma'i 29moi",
#    'jv': '29 Juni',
#    'ka': '29 ივნისი',
#    'kk': '29 маусым',
#    'kl': 'Juuni 29',
#    'kn': 'ಜೂನ್ ೨೯',
#    'ko': '6월 29일',
#    'krc': '29 июнь',
#    'ksh': '29. Juuni',
#    'ku': "29'ê pûşperê",
#    'kv': '29 лӧддза-номъя',
#    'ky': '29 июнь',
#    'la': '29 Iunii',
#    'lb': '29. Juni',
#    'li': '29 juni',
#    'lmo': '29 06',
#    'lt': 'Birželio 29',
#    'lv': '29. jūnijs',
#    'mai': '२९ जुन',
#    'map-bms': '29 Juni',
#    'mg': '29 Jiona',
#    'mhr': '29 Пеледыш',
#    'mk': '29 јуни',
#    'ml': 'ജൂൺ 29',
#    'mn': '6 сарын 29',
#    'mr': 'जून २९',
#    'ms': '29 Jun',
#    'my': '၂၉ ဇွန်',
#    'myv': 'Аштемковонь 29 чи',
#    'nah': 'Tlachicuazti 29',
#    'nap': "29 'e giùgno",
#    'nds': '29. Juni',
#    'nds-nl': '29 juni',
#    'ne': '२९ जुन',
#    'new': 'जुन २९',
#    'nl': '29 juni',
#    'nn': '29. juni',
#    'no': '29. juni',
#    'nov': '29 de june',
#    'nrm': '29 Juîn',
#    'nso': 'Phupu 29',
#    'oc': '29 de junh',
#    'olo': '29. kezäkuudu',
#    'or': '୨୯ ଜୁନ',
#    'pa': '29 ਜੂਨ',
#    'pag': 'June 29',
#    'pam': 'Juniu 29',
#    'pl': '29 czerwca',
#    'pnb': '29 جون',
#    'pt': '29 de junho',
#    'qu': '29 ñiqin inti raymi killapi',
#    'ro': '29 iunie',
#    'ru': '29 июня',
#    'rue': '29. юн',
#    'sa': '२९ जून',
#    'sah': 'Бэс ыйын 29',
#    'scn': '29 di giugnu',
#    'sco': '29 Juin',
#    'se': 'Geassemánu 29.',
#    'sh': '29. 6.',
#    'simple': 'June 29',
#    'sk': '29. jún',
#    'sl': '29. junij',
#    'sq': '29 Qershor',
#    'sr': '29. јун',
#    'su': '29 Juni',
#    'sv': '29 juni',
#    'sw': '29 Juni',
#    'ta': 'ஜூன் 29',
#    'te': 'జూన్ 29',
#    'tg': '29 июн',
#    'th': '29 มิถุนายน',
#    'tk': '29 iýun',
#    'tl': 'Hunyo 29',
#    'tr': '29 Haziran',
#    'tt': '29 июнь',
#    'uk': '29 червня',
#    'ur': '29 جون',
#    'uz': '29-iyun',
#    'vec': '29 de giugno',
#    'vi': '29 tháng 6',
#    'vls': '29 juni',
#    'vo': 'Yunul 29',
#    'wa': '29 di djun',
#    'war': 'Hunyo 29',
#    'xal': 'Мөчн сарин 29',
#    'xmf': '29 მანგი',
#    'yi': '29סטן יוני',
#    'yo': '29 June',
#    'zh': '6月29日',
#    'zh-min-nan': '6 goe̍h 29 ji̍t',
#    'zh-yue': '6月29號'},
#   '5 ביולי': {'ab': 'Ҧхынгәы 5',
#    'af': '5 Julie',
#    'als': '5. Juli',
#    'am': '5 July',
#    'an': '5 de chulio',
#    'ar': '5 يوليو',
#    'arz': '5 يوليه',
#    'as': '৫ জুলাই',
#    'ast': '5 de xunetu',
#    'av': '5 Июл',
#    'az': '5 iyul',
#    'ba': '5 июль',
#    'bat-smg': 'Lėipas 5',
#    'bcl': 'Hulyo 5',
#    'be': '5 ліпеня',
#    'be-x-old': '5 ліпеня',
#    'bg': '5 юли',
#    'bh': '५ जुलाई',
#    'bn': '৫ জুলাই',
#    'bpy': 'জুলাই ৫',
#    'br': '5 Gouere',
#    'bs': '5. juli',
#    'ca': '5 de juliol',
#    'cdo': '7 nguŏk 5 hô̤',
#    'ce': '5 июль',
#    'ceb': 'Hulyo 5',
#    'ckb': '٥ی تەممووز',
#    'co': '5 di lugliu',
#    'cs': '5. červenec',
#    'csb': '5 lëpińca',
#    'cv': 'Утă, 5',
#    'cy': '5 Gorffennaf',
#    'da': '5. juli',
#    'de': '5. Juli',
#    'diq': '5 Temuz',
#    'dv': 'ޖުލައި 5',
#    'ee': 'Siamlɔm 5',
#    'el': '5 Ιουλίου',
#    'eml': '5 ed lói',
#    'en': 'July 5',
#    'eo': '5-a de julio',
#    'es': '5 de julio',
#    'et': '5. juuli',
#    'eu': 'Uztailaren 5',
#    'ext': '5 júliu',
#    'fa': '۵ ژوئیه',
#    'fi': '5. heinäkuuta',
#    'fiu-vro': '5. hainakuu päiv',
#    'fo': '5. juli',
#    'fr': '5 juillet',
#    'frp': '5 j·ulyèt',
#    'fur': '5 di Lui',
#    'fy': '5 july',
#    'ga': '5 Iúil',
#    'gag': '5 Orak ay',
#    'gan': '7月5號',
#    'gd': '5 an t-Iuchar',
#    'gl': '5 de xullo',
#    'gu': 'જુલાઇ ૫',
#    'gv': '5 Jerrey Souree',
#    'hak': '7-ngie̍t 5-ngit',
#    'hi': '५ जुलाई',
#    'hif': '5 July',
#    'hr': '5. srpnja',
#    'hsb': '5. julija',
#    'ht': '5 jiyè',
#    'hu': 'Július 5.',
#    'hy': 'Հուլիսի 5',
#    'ia': '5 de julio',
#    'id': '5 Juli',
#    'ie': '5 juli',
#    'ig': '5 Julaị',
#    'ilo': 'Hulio 5',
#    'io': '5 di julio',
#    'is': '5. júlí',
#    'it': '5 luglio',
#    'ja': '7月5日',
#    'jv': '5 Juli',
#    'ka': '5 ივლისი',
#    'kab': '5 yulyu',
#    'kk': '5 шілде',
#    'kl': 'Juuli 5',
#    'kn': 'ಜುಲೈ ೫',
#    'ko': '7월 5일',
#    'krc': '5 июль',
#    'ksh': '5. Juuli',
#    'ku': "5'ê tîrmehê",
#    'kv': '5 сора',
#    'la': '5 Iulii',
#    'lb': '5. Juli',
#    'li': '5 juli',
#    'lmo': '05 07',
#    'lt': 'Liepos 5',
#    'lv': '5. jūlijs',
#    'mai': '५ जुलाई',
#    'mg': '5 Jolay',
#    'mhr': '5 Сӱрем',
#    'mk': '5 јули',
#    'ml': 'ജൂലൈ 5',
#    'mn': '7 сарын 5',
#    'mr': 'जुलै ५',
#    'ms': '5 Julai',
#    'my': '၅ ဇူလိုင်',
#    'myv': 'Медьковонь 5 чи',
#    'nah': 'Tlachicōnti 5',
#    'nap': "5 'e luglio",
#    'nds': '5. Juli',
#    'nds-nl': '5 juli',
#    'ne': '५ जुलाई',
#    'new': 'जुलाई ५',
#    'nl': '5 juli',
#    'nn': '5. juli',
#    'no': '5. juli',
#    'nrm': '5 Juilet',
#    'nso': 'Mosegamanye 5',
#    'oc': '5 de julhet',
#    'olo': '5. heinykuudu',
#    'or': '୫ ଜୁଲାଇ',
#    'pa': '5 ਜੁਲਾਈ',
#    'pag': 'July 5',
#    'pam': 'Juliu 5',
#    'pl': '5 lipca',
#    'pnb': '5 جولائی',
#    'pt': '5 de julho',
#    'qu': '5 ñiqin anta situwa killapi',
#    'ro': '5 iulie',
#    'ru': '5 июля',
#    'rue': '5. юл',
#    'sa': '५ जुलाई',
#    'sah': 'От ыйын 5',
#    'scn': '5 di giugnettu',
#    'sco': '5 Julie',
#    'se': 'Suoidnemánu 5.',
#    'sh': '5. 7.',
#    'simple': 'July 5',
#    'sk': '5. júl',
#    'sl': '5. julij',
#    'sq': '5 Korrik',
#    'sr': '5. јул',
#    'su': '5 Juli',
#    'sv': '5 juli',
#    'sw': '5 Julai',
#    'ta': 'சூலை 5',
#    'te': 'జూలై 5',
#    'tg': '5 июл',
#    'th': '5 กรกฎาคม',
#    'tk': '5 iýul',
#    'tl': 'Hulyo 5',
#    'tr': '5 Temmuz',
#    'tt': '5 июль',
#    'uk': '5 липня',
#    'ur': '5 جولائی',
#    'uz': '5-iyul',
#    'vec': '5 de lujo',
#    'vi': '5 tháng 7',
#    'vls': '5 juli',
#    'vo': 'Yulul 5',
#    'wa': '5 di djulete',
#    'war': 'Hulyo 5',
#    'xal': 'Така сарин 5',
#    'xmf': '5 კვირკვე',
#    'yi': '5טן יולי',
#    'yo': '5 July',
#    'zea': '5 juli',
#    'zh': '7月5日',
#    'zh-min-nan': '7 goe̍h 5 ji̍t',
#    'zh-yue': '7月5號'},
#   '7 ביולי': {'ab': 'Ҧхынгәы 7',
#    'af': '7 Julie',
#    'als': '7. Juli',
#    'am': '7 July',
#    'an': '7 de chulio',
#    'ar': '7 يوليو',
#    'arz': '7 يوليه',
#    'as': '৭ জুলাই',
#    'ast': '7 de xunetu',
#    'av': '7 Июл',
#    'az': '7 iyul',
#    'ba': '7 июль',
#    'bat-smg': 'Lėipas 7',
#    'bcl': 'Hulyo 7',
#    'be': '7 ліпеня',
#    'be-x-old': '7 ліпеня',
#    'bg': '7 юли',
#    'bh': '७ जुलाई',
#    'bn': '৭ জুলাই',
#    'bpy': 'জুলাই ৭',
#    'br': '7 Gouere',
#    'bs': '7. juli',
#    'ca': '7 de juliol',
#    'cdo': '7 nguŏk 7 hô̤',
#    'ce': '7 июль',
#    'ceb': 'Hulyo 7',
#    'ckb': '٧ی تەممووز',
#    'co': '7 di lugliu',
#    'cs': '7. červenec',
#    'csb': '7 lëpińca',
#    'cv': 'Утă, 7',
#    'cy': '7 Gorffennaf',
#    'da': '7. juli',
#    'de': '7. Juli',
#    'diq': '7 Temuz',
#    'dv': 'ޖުލައި 7',
#    'el': '7 Ιουλίου',
#    'eml': '7 ed lói',
#    'en': 'July 7',
#    'eo': '7-a de julio',
#    'es': '7 de julio',
#    'et': '7. juuli',
#    'eu': 'Uztailaren 7',
#    'ext': '7 júliu',
#    'fa': '۷ ژوئیه',
#    'fi': '7. heinäkuuta',
#    'fiu-vro': '7. hainakuu päiv',
#    'fo': '7. juli',
#    'fr': '7 juillet',
#    'frp': '7 j·ulyèt',
#    'fur': '7 di Lui',
#    'fy': '7 july',
#    'ga': '7 Iúil',
#    'gag': '7 Orak ay',
#    'gan': '7月7號',
#    'gd': '7 an t-Iuchar',
#    'gl': '7 de xullo',
#    'gu': 'જુલાઇ ૭',
#    'gv': '7 Jerrey Souree',
#    'hak': '7-ngie̍t 7-ngit',
#    'hi': '७ जुलाई',
#    'hif': '7 July',
#    'hr': '7. srpnja',
#    'hsb': '7. julija',
#    'ht': '7 jiyè',
#    'hu': 'Július 7.',
#    'hy': 'Հուլիսի 7',
#    'ia': '7 de julio',
#    'id': '7 Juli',
#    'ie': '7 juli',
#    'ig': '7 Julaị',
#    'ilo': 'Hulio 7',
#    'io': '7 di julio',
#    'is': '7. júlí',
#    'it': '7 luglio',
#    'ja': '7月7日',
#    'jv': '7 Juli',
#    'ka': '7 ივლისი',
#    'kk': '7 шілде',
#    'kl': 'Juuli 7',
#    'km': '៧ កក្កដា',
#    'kn': 'ಜುಲೈ ೭',
#    'ko': '7월 7일',
#    'krc': '7 июль',
#    'ku': "7'ê tîrmehê",
#    'kv': '7 сора',
#    'la': '7 Iulii',
#    'lb': '7. Juli',
#    'li': '7 juli',
#    'lmo': '07 07',
#    'lt': 'Liepos 7',
#    'lv': '7. jūlijs',
#    'mai': '७ जुलाई',
#    'mg': '7 Jolay',
#    'mhr': '7 Сӱрем',
#    'mk': '7 јули',
#    'ml': 'ജൂലൈ 7',
#    'mn': '7 сарын 7',
#    'mr': 'जुलै ७',
#    'ms': '7 Julai',
#    'my': '၇ ဇူလိုင်',
#    'myv': 'Медьковонь 7 чи',
#    'nah': 'Tlachicōnti 7',
#    'nap': "7 'e luglio",
#    'nds': '7. Juli',
#    'nds-nl': '7 juli',
#    'ne': '७ जुलाई',
#    'new': 'जुलाई ७',
#    'nl': '7 juli',
#    'nn': '7. juli',
#    'no': '7. juli',
#    'nrm': '7 Juilet',
#    'nso': 'Mosegamanye 7',
#    'oc': '7 de julhet',
#    'olo': '7. heinykuudu',
#    'or': '୭ ଜୁଲାଇ',
#    'os': '7 июлы',
#    'pa': '7 ਜੁਲਾਈ',
#    'pag': 'July 7',
#    'pam': 'Juliu 7',
#    'pl': '7 lipca',
#    'pnb': '7 جولائی',
#    'pt': '7 de julho',
#    'qu': '7 ñiqin anta situwa killapi',
#    'ro': '7 iulie',
#    'ru': '7 июля',
#    'rue': '7. юл',
#    'sa': '७ जुलाई',
#    'sah': 'От ыйын 7',
#    'scn': '7 di giugnettu',
#    'sco': '7 Julie',
#    'se': 'Suoidnemánu 7.',
#    'sh': '7. 7.',
#    'simple': 'July 7',
#    'sk': '7. júl',
#    'sl': '7. julij',
#    'sq': '7 Korrik',
#    'sr': '7. јул',
#    'su': '7 Juli',
#    'sv': '7 juli',
#    'sw': '7 Julai',
#    'ta': 'சூலை 7',
#    'te': 'జూలై 7',
#    'tg': '7 июл',
#    'th': '7 กรกฎาคม',
#    'tk': '7 iýul',
#    'tl': 'Hulyo 7',
#    'tr': '7 Temmuz',
#    'tt': '7 июль',
#    'uk': '7 липня',
#    'ur': '7 جولائی',
#    'uz': '7-iyul',
#    'vec': '7 de lujo',
#    'vi': '7 tháng 7',
#    'vls': '7 juli',
#    'vo': 'Yulul 7',
#    'wa': '7 di djulete',
#    'war': 'Hulyo 7',
#    'xal': 'Така сарин 7',
#    'xmf': '7 კვირკვე',
#    'yi': '7טן יולי',
#    'yo': '7 July',
#    'zh': '7月7日',
#    'zh-min-nan': '7 goe̍h 7 ji̍t',
#    'zh-yue': '7月7號'},
#   '8 ביוני': {'ab': 'Рашәара 8',
#    'af': '8 Junie',
#    'als': '8. Juni',
#    'am': '8 June',
#    'an': '8 de chunio',
#    'ar': '8 يونيو',
#    'arz': '8 يونيه',
#    'as': '৮ জুন',
#    'ast': '8 de xunu',
#    'av': '8 Июн',
#    'az': '8 iyun',
#    'ba': '8 июнь',
#    'bat-smg': 'Bėrželė 8',
#    'bcl': 'Hunyo 8',
#    'be': '8 чэрвеня',
#    'be-x-old': '8 чэрвеня',
#    'bg': '8 юни',
#    'bh': '८ जून',
#    'bn': '৮ জুন',
#    'bpy': 'জুন ৮',
#    'br': '8 Mezheven',
#    'bs': '8. juni',
#    'ca': '8 de juny',
#    'cdo': '6 nguŏk 8 hô̤',
#    'ce': '8 июнь',
#    'ceb': 'Hunyo 8',
#    'ckb': '٨ی حوزەیران',
#    'co': '8 di ghjugnu',
#    'cs': '8. červen',
#    'csb': '8 czerwińca',
#    'cv': 'Çĕртме, 8',
#    'cy': '8 Mehefin',
#    'da': '8. juni',
#    'de': '8. Juni',
#    'diq': '8 Heziran',
#    'dv': 'ޖޫން 8',
#    'el': '8 Ιουνίου',
#    'eml': '8 ed zógn',
#    'en': 'June 8',
#    'eo': '8-a de junio',
#    'es': '8 de junio',
#    'et': '8. juuni',
#    'eu': 'Ekainaren 8',
#    'ext': '8 juñu',
#    'fa': '۸ ژوئن',
#    'fi': '8. kesäkuuta',
#    'fiu-vro': '8. piimäkuu päiv',
#    'fo': '8. juni',
#    'fr': '8 juin',
#    'frp': '8 jouen',
#    'fur': '8 di Jugn',
#    'fy': '8 juny',
#    'ga': '8 Meitheamh',
#    'gag': '8 Kirez ay',
#    'gan': '6月8號',
#    'gd': '8 an t-Ògmhios',
#    'gl': '8 de xuño',
#    'gu': 'જૂન ૮',
#    'gv': '8 Mean Souree',
#    'hak': '6-ngie̍t 8-ngit',
#    'hi': '८ जून',
#    'hif': '8 June',
#    'hr': '8. lipnja',
#    'hsb': '8. junija',
#    'ht': '8 jen',
#    'hu': 'Június 8.',
#    'hy': 'Հունիսի 8',
#    'ia': '8 de junio',
#    'id': '8 Juni',
#    'ie': '8 junio',
#    'ig': 'Önwa ishií 8',
#    'ilo': 'Hunio 8',
#    'io': '8 di junio',
#    'is': '8. júní',
#    'it': '8 giugno',
#    'ja': '6月8日',
#    'jv': '8 Juni',
#    'ka': '8 ივნისი',
#    'kk': '8 маусым',
#    'kl': 'Juuni 8',
#    'kn': 'ಜೂನ್ ೮',
#    'ko': '6월 8일',
#    'krc': '8 июнь',
#    'ksh': '8. Juuni',
#    'ku': "8'ê pûşperê",
#    'kv': '8 лӧддза-номъя',
#    'ky': '8-июнь',
#    'la': '8 Iunii',
#    'lb': '8. Juni',
#    'li': '8 juni',
#    'lmo': '08 06',
#    'lt': 'Birželio 8',
#    'lv': '8. jūnijs',
#    'mai': '८ जुन',
#    'mhr': '8 Пеледыш',
#    'mi': '8 Pipiri',
#    'mk': '8 јуни',
#    'ml': 'ജൂൺ 8',
#    'mn': '6 сарын 8',
#    'mr': 'जून ८',
#    'ms': '8 Jun',
#    'my': '၈ ဇွန်',
#    'myv': 'Аштемковонь 8 чи',
#    'nah': '8 Tlachicuazti',
#    'nap': "8 'e giùgno",
#    'nds': '8. Juni',
#    'nds-nl': '8 juni',
#    'ne': '८ जुन',
#    'new': 'जुन ८',
#    'nl': '8 juni',
#    'nn': '8. juni',
#    'no': '8. juni',
#    'nrm': '8 Juîn',
#    'nso': 'Phupu 8',
#    'oc': '8 de junh',
#    'olo': '8. kezäkuudu',
#    'or': '୮ ଜୁନ',
#    'pa': '8 ਜੂਨ',
#    'pag': 'June 8',
#    'pam': 'Juniu 8',
#    'pl': '8 czerwca',
#    'pnb': '8 جون',
#    'pt': '8 de junho',
#    'qu': '8 ñiqin inti raymi killapi',
#    'ro': '8 iunie',
#    'ru': '8 июня',
#    'rue': '8. юн',
#    'sa': '८ जून',
#    'sah': 'Бэс ыйын 8',
#    'scn': '8 di giugnu',
#    'sco': '8 Juin',
#    'se': 'Geassemánu 8.',
#    'sh': '8. 6.',
#    'simple': 'June 8',
#    'sk': '8. jún',
#    'sl': '8. junij',
#    'sq': '8 Qershor',
#    'sr': '8. јун',
#    'stq': '8. Juni',
#    'su': '8 Juni',
#    'sv': '8 juni',
#    'sw': '8 Juni',
#    'ta': 'ஜூன் 8',
#    'te': 'జూన్ 8',
#    'tg': '8 июн',
#    'th': '8 มิถุนายน',
#    'tk': '8 iýun',
#    'tl': 'Hunyo 8',
#    'tr': '8 Haziran',
#    'tt': '8 июнь',
#    'uk': '8 червня',
#    'ur': '8 جون',
#    'uz': '8-iyun',
#    'vec': '8 de giugno',
#    'vi': '8 tháng 6',
#    'vls': '8 juni',
#    'vo': 'Yunul 8',
#    'wa': '8 di djun',
#    'war': 'Hunyo 8',
#    'xal': 'Мөчн сарин 8',
#    'xmf': '8 მანგი',
#    'yi': '8טן יוני',
#    'yo': '8 June',
#    'zh': '6月8日',
#    'zh-min-nan': '6 goe̍h 8 ji̍t',
#    'zh-yue': '6月8號'},
#   '9 ביולי': {'ab': 'Ҧхынгәы 9',
#    'af': '9 Julie',
#    'als': '9. Juli',
#    'am': '9 July',
#    'an': '9 de chulio',
#    'ar': '9 يوليو',
#    'arz': '9 يوليه',
#    'as': '৯ জুলাই',
#    'ast': '9 de xunetu',
#    'av': '9 Июл',
#    'az': '9 iyul',
#    'ba': '9 июль',
#    'bat-smg': 'Lėipas 9',
#    'bcl': 'Hulyo 9',
#    'be': '9 ліпеня',
#    'be-x-old': '9 ліпеня',
#    'bg': '9 юли',
#    'bh': '९ जुलाई',
#    'bn': '৯ জুলাই',
#    'bpy': 'জুলাই ৯',
#    'br': '9 Gouere',
#    'bs': '9. juli',
#    'ca': '9 de juliol',
#    'cdo': '7 nguŏk 9 hô̤',
#    'ce': '9 июль',
#    'ceb': 'Hulyo 9',
#    'ckb': '٩ی تەممووز',
#    'co': '9 di lugliu',
#    'cs': '9. červenec',
#    'csb': '9 lëpińca',
#    'cv': 'Утă, 9',
#    'cy': '9 Gorffennaf',
#    'da': '9. juli',
#    'de': '9. Juli',
#    'diq': '9 Temuz',
#    'dv': 'ޖުލައި 9',
#    'el': '9 Ιουλίου',
#    'eml': '9 ed lói',
#    'en': 'July 9',
#    'eo': '9-a de julio',
#    'es': '9 de julio',
#    'et': '9. juuli',
#    'eu': 'Uztailaren 9',
#    'ext': '9 júliu',
#    'fa': '۹ ژوئیه',
#    'fi': '9. heinäkuuta',
#    'fiu-vro': '9. hainakuu päiv',
#    'fo': '9. juli',
#    'fr': '9 juillet',
#    'frp': '9 j·ulyèt',
#    'fur': '9 di Lui',
#    'fy': '9 july',
#    'ga': '9 Iúil',
#    'gag': '9 Orak ay',
#    'gan': '7月9號',
#    'gd': '9 an t-Iuchar',
#    'gl': '9 de xullo',
#    'gu': 'જુલાઇ ૯',
#    'gv': '9 Jerrey Souree',
#    'hak': '7-ngie̍t 9-ngit',
#    'hi': '९ जुलाई',
#    'hif': '9 July',
#    'hr': '9. srpnja',
#    'hsb': '9. julija',
#    'ht': '9 jiyè',
#    'hu': 'Július 9.',
#    'hy': 'Հուլիսի 9',
#    'ia': '9 de julio',
#    'id': '9 Juli',
#    'ie': '9 juli',
#    'ig': '9 Julaị',
#    'ilo': 'Hulio 9',
#    'io': '9 di julio',
#    'is': '9. júlí',
#    'it': '9 luglio',
#    'ja': '7月9日',
#    'jv': '9 Juli',
#    'ka': '9 ივლისი',
#    'kk': '9 шілде',
#    'kl': 'Juuli 9',
#    'kn': 'ಜುಲೈ ೯',
#    'ko': '7월 9일',
#    'krc': '9 июль',
#    'ksh': '9. Juuli',
#    'ku': "9'ê tîrmehê",
#    'kv': '9 сора',
#    'la': '9 Iulii',
#    'lb': '9. Juli',
#    'li': '9 juli',
#    'lmo': '09 07',
#    'lt': 'Liepos 9',
#    'lv': '9. jūlijs',
#    'mai': '९ जुलाई',
#    'mg': '9 Jolay',
#    'mhr': '9 Сӱрем',
#    'mk': '9 јули',
#    'ml': 'ജൂലൈ 9',
#    'mn': '7 сарын 9',
#    'mr': 'जुलै ९',
#    'ms': '9 Julai',
#    'my': '၉ ဇူလိုင်',
#    'myv': 'Медьковонь 9 чи',
#    'nah': 'Tlachicōnti 9',
#    'nap': "9 'e luglio",
#    'nds': '9. Juli',
#    'nds-nl': '9 juli',
#    'ne': '९ जुलाई',
#    'new': 'जुलाई ९',
#    'nl': '9 juli',
#    'nn': '9. juli',
#    'no': '9. juli',
#    'nrm': '9 Juilet',
#    'nso': 'Mosegamanye 9',
#    'oc': '9 de julhet',
#    'olo': '9. heinykuudu',
#    'or': '୯ ଜୁଲାଇ',
#    'pa': '9 ਜੁਲਾਈ',
#    'pag': 'July 9',
#    'pam': 'Juliu 9',
#    'pl': '9 lipca',
#    'pnb': '9 جولائی',
#    'pnt': '9 Χορτοθερί',
#    'pt': '9 de julho',
#    'qu': '9 ñiqin anta situwa killapi',
#    'ro': '9 iulie',
#    'ru': '9 июля',
#    'rue': '9. юл',
#    'sa': '९ जुलाई',
#    'sah': 'От ыйын 9',
#    'scn': '9 di giugnettu',
#    'sco': '9 Julie',
#    'se': 'Suoidnemánu 9.',
#    'sh': '9. 7.',
#    'simple': 'July 9',
#    'sk': '9. júl',
#    'sl': '9. julij',
#    'sq': '9 Korrik',
#    'sr': '9. јул',
#    'su': '9 Juli',
#    'sv': '9 juli',
#    'sw': '9 Julai',
#    'szl': '9 lipca',
#    'ta': 'சூலை 9',
#    'te': 'జూలై 9',
#    'tg': '9 июл',
#    'th': '9 กรกฎาคม',
#    'tk': '9 iýul',
#    'tl': 'Hulyo 9',
#    'tr': '9 Temmuz',
#    'ts': 'Mawuwani 9',
#    'tt': '9 июль',
#    'uk': '9 липня',
#    'ur': '9 جولائی',
#    'uz': '9-iyul',
#    'vec': '9 de lujo',
#    'vi': '9 tháng 7',
#    'vls': '9 juli',
#    'vo': 'Yulul 9',
#    'wa': '9 di djulete',
#    'war': 'Hulyo 9',
#    'xal': 'Така сарин 9',
#    'xmf': '9 კვირკვე',
#    'yi': '9טן יולי',
#    'yo': '9 July',
#    'zea': '9 juli',
#    'zh': '7月9日',
#    'zh-min-nan': '7 goe̍h 9 ji̍t',
#    'zh-yue': '7月9號'},
#   'Ynet': {'ca': 'Ynet',
#    'cs': 'Ynet',
#    'de': 'Ynet',
#    'en': 'Ynet',
#    'es': 'Ynet',
#    'fr': 'Ynet',
#    'ja': 'Yネット',
#    'ko': 'Ynet',
#    'lad': 'YNet',
#    'yi': 'Ynet'},
#   'ארגון טרור': {'de': 'Terroristische Vereinigung',
#    'diq': 'Organizasyono terorist',
#    'ru': 'Террористическая организация',
#    'uk': 'Терористична організація'},
#   'אש"ף': {'af': 'Palestynse Bevrydingsorganisasie',
#    'ang': 'Palistiniscre Frēogunge Þēodnes',
#    'ar': 'منظمة التحرير الفلسطينية',
#    'arz': 'منظمة التحرير الفلسطينيه',
#    'az': 'Fələstin Azadlıq Təşkilatı',
#    'bg': 'Организация за освобождение на Палестина',
#    'bn': 'মুনাজ্জামাত আল-তাহরির আল-ফিলিস্তিনিয়া',
#    'bs': 'Palestinska oslobodilačka organizacija',
#    'ca': "Organització per a l'Alliberament de Palestina",
#    'ceb': 'Kapunongan para sa Kagawasan sa Palestina',
#    'cs': 'Organizace pro osvobození Palestiny',
#    'cy': 'Mudiad Rhyddid Palesteina',
#    'da': 'PLO',
#    'de': 'Palästinensische Befreiungsorganisation',
#    'el': 'Οργάνωση για την Απελευθέρωση της Παλαιστίνης',
#    'en': 'Palestine Liberation Organization',
#    'eo': 'Organizaĵo por Liberigo de Palestino',
#    'es': 'Organización para la Liberación de Palestina',
#    'et': 'Palestiina Vabastusorganisatsioon',
#    'eu': 'Palestinaren Askapenerako Erakundea',
#    'fa': 'سازمان آزادی\u200cبخش فلسطین',
#    'fi': 'Palestiinan vapautusjärjestö',
#    'fr': 'Organisation de libération de la Palestine',
#    'frr': 'PLO',
#    'gl': 'Organización para a Liberación de Palestina',
#    'hi': 'फिलिस्तीनी मुक्ति संगठन',
#    'hr': 'Palestinska oslobodilačka organizacija',
#    'hu': 'Palesztinai Felszabadítási Szervezet',
#    'hy': 'Պաղեստինի ազատության կազմակերպություն',
#    'id': 'Organisasi Pembebasan Palestina',
#    'it': 'Organizzazione per la Liberazione della Palestina',
#    'ja': 'パレスチナ解放機構',
#    'ka': 'პალესტინის გათავისუფლების ორგანიზაცია',
#    'ko': '팔레스타인 해방 기구',
#    'la': 'Ordo Palaestinae liberandae',
#    'lt': 'Palestinos išsivadavimo organizacija',
#    'lv': 'Palestīnas Atbrīvošanas organizācija',
#    'mk': 'Палестинска ослободителна организација',
#    'ml': 'പലസ്തീൻ ലിബറേഷൻ ഓർഗനൈസേഷൻ',
#    'ms': 'Pertubuhan Pembebasan Palestin',
#    'nl': 'Palestijnse Bevrijdingsorganisatie',
#    'nn': 'Den palestinske frigjeringsorganisasjonen',
#    'no': 'Palestinas frigjøringsorganisasjon',
#    'oc': 'Organizacion de Liberacion de Palestina',
#    'pa': 'ਫ਼ਲਸਤੀਨ ਮੁਕਤੀ ਸੰਗਠਨ',
#    'pl': 'Organizacja Wyzwolenia Palestyny',
#    'pt': 'Organização para a Libertação da Palestina',
#    'ro': 'Organizația pentru Eliberarea Palestinei',
#    'ru': 'Организация освобождения Палестины',
#    'sh': 'Palestinska oslobodilačka organizacija',
#    'simple': 'Palestine Liberation Organization',
#    'sk': 'Organizácia za oslobodenie Palestíny',
#    'sr': 'Палестинска ослободилачка организација',
#    'su': 'Organisasi Pabébasan Paléstina',
#    'sv': 'Palestinska befrielseorganisationen',
#    'ta': 'பலத்தீன விடுதலை இயக்கம்',
#    'th': 'องค์การปลดปล่อยปาเลสไตน์',
#    'tl': 'Palestinian Liberation Organization',
#    'tr': 'Filistin Kurtuluş Örgütü',
#    'uk': 'Організація визволення Палестини',
#    'ur': 'تنظیم آزادی فلسطین',
#    'vi': 'Tổ chức Giải phóng Palestine',
#    'yi': 'פאלעסטין באפרייונג ארגאניזאציע',
#    'zh': '巴勒斯坦解放組織',
#    'zh-yue': '巴勒斯坦解放組織'},
#   'בית המשפט החוקתי העליון של מצרים (הדף אינו קיים)': {},
#   'גרילה': {'ar': 'حرب عصابات',
#    'az': 'Partizan müharibəsi',
#    'bar': 'Guerillakriag',
#    'be': 'Партызанская вайна',
#    'bg': 'Партизанска война',
#    'bn': 'গেরিলা যুদ্ধ',
#    'br': 'Gouvrezel',
#    'bs': 'Gerilsko ratovanje',
#    'ca': 'Guerrilla',
#    'cs': 'Partyzánská válka',
#    'cy': 'Rhyfela herwfilwrol',
#    'da': 'Guerillakrig',
#    'de': 'Guerilla',
#    'el': 'Ανταρτοπόλεμος',
#    'en': 'Guerrilla warfare',
#    'eo': 'Gerilo',
#    'es': 'Guerra de guerrillas',
#    'eu': 'Gerrilla',
#    'fa': 'جنگ چریکی',
#    'fi': 'Sissisota',
#    'fr': 'Guérilla',
#    'ga': 'Treallchogaíocht',
#    'gl': 'Loita de guerrillas',
#    'hi': 'गोरिल्ला युद्ध',
#    'hr': 'Gerilsko ratovanje',
#    'hu': 'Gerilla-hadviselés',
#    'hy': 'Գերիլիա',
#    'id': 'Gerilya',
#    'is': 'Skæruhernaður',
#    'it': 'Guerriglia',
#    'ja': 'ゲリラ',
#    'kk': 'Партизандық соғыс',
#    'ko': '유격전',
#    'ku': 'Gerîla',
#    'la': 'Bellum clandestinum',
#    'lt': 'Partizaninis karas',
#    'lv': 'Partizānu karš',
#    'ml': 'ഗറില്ലായുദ്ധം',
#    'mr': 'गनिमी कावा',
#    'ms': 'Gerila',
#    'mzn': 'چریک',
#    'nl': 'Guerrilla',
#    'nn': 'Gerilja',
#    'no': 'Geriljakrig',
#    'nrm': 'Dgèrrilleux',
#    'pl': 'Partyzantka',
#    'pt': 'Guerrilha',
#    'ro': 'Război de gherilă',
#    'ru': 'Партизанская война',
#    'sco': 'Guerrilla warfare',
#    'sh': 'Gerilski rat',
#    'si': 'ගරිල්ලා යුධ වැදීම්',
#    'simple': 'Guerrilla warfare',
#    'sk': 'Partizánska vojna',
#    'sl': 'Gverilsko bojevanje',
#    'sr': 'Мали рат',
#    'sv': 'Gerillakrigföring',
#    'ta': 'கரந்தடிப் போர் முறை',
#    'th': 'การสงครามกองโจร',
#    'tl': 'Pakikidigmang gerilya',
#    'tr': 'Gerilla savaşı',
#    'uk': 'Партизанська війна',
#    'ur': 'گوریلا جنگ',
#    'vi': 'Chiến tranh du kích',
#    'zh': '游击战'},
#   'האומות המאוחדות': {'ab': 'Еидгылоу Амилаҭқәа Рорганизациа',
#    'ady': 'Дунэе Лъэпкъ Организацие',
#    'af': 'Verenigde Nasies',
#    'als': 'Vereinte Nationen',
#    'am': 'የተባበሩት መንግሥታት ድርጅት',
#    'an': "Organización d'as Nacions Unitas",
#    'ar': 'الأمم المتحدة',
#    'arz': 'الأمم المتحده',
#    'as': 'ৰাষ্ট্ৰসংঘ',
#    'ast': 'Organización de les Naciones Xuníes',
#    'av': 'Цолъарал Миллатазул ГІуцІи',
#    'az': 'Birləşmiş Millətlər Təşkilatı',
#    'azb': 'بیرلشمیش میلتلر قورومو',
#    'ba': 'Берләшкән Милләттәр Ойошмаһы',
#    'bar': 'UNO',
#    'bat-smg': 'Jongtėniu Tautū Uorganėzacėjė',
#    'bcl': 'Nagkakasararong Nacion',
#    'be': "Арганізацыя Аб'яднаных Нацый",
#    'be-x-old': 'Арганізацыя Аб’яднаных Нацыяў',
#    'bg': 'Организация на обединените нации',
#    'bi': 'Yunaeted Nesen',
#    'bn': 'জাতিসংঘ',
#    'bo': 'མཉམ་འབྲེལ་རྒྱལ་ཚོགས།',
#    'bpy': 'জাতিসংঘ',
#    'br': 'Aozadur ar Broadoù Unanet',
#    'bs': 'Ujedinjene nacije',
#    'bxr': 'Нэгэдэһэн Үндэһэтэнэй Байгуулга',
#    'ca': 'Organització de les Nacions Unides',
#    'cdo': 'Lièng-hăk-guók',
#    'ce': 'Вовшахкхетта Къаьмнийн Организаци',
#    'ceb': 'Hiniusang mga Nasod',
#    'ckb': 'نەتەوە یەکگرتووەکان',
#    'crh': 'Birleşken Milletler Teşkilâtı',
#    'cs': 'Organizace spojených národů',
#    'cv': 'Пĕрлешнĕ Нацисен Организацийĕ',
#    'cy': 'Y Cenhedloedd Unedig',
#    'da': 'Forenede Nationer',
#    'de': 'Vereinte Nationen',
#    'diq': 'Mıletê Yewbiyayey',
#    'dsb': 'Zjadnośone narody',
#    'dv': 'އެކުވެރި ދައުލަތްތައް',
#    'el': 'Οργανισμός Ηνωμένων Εθνών',
#    'en': 'United Nations',
#    'eo': 'Unuiĝintaj Nacioj',
#    'es': 'Organización de las Naciones Unidas',
#    'et': 'Ühinenud Rahvaste Organisatsioon',
#    'eu': 'Nazio Batuen Erakundea',
#    'ext': 'Nacionis Unías',
#    'fa': 'سازمان ملل متحد',
#    'fi': 'Yhdistyneet kansakunnat',
#    'fiu-vro': 'Ütistünüq Rahvaq',
#    'fo': 'Sameindu Tjóðir',
#    'fr': 'Organisation des Nations unies',
#    'frp': 'Organisacion des Nacions unies',
#    'frr': 'Feriand Natjuunen',
#    'fur': 'Organizazion des Nazions Unidis',
#    'fy': 'Feriene Naasjes',
#    'ga': 'Na Náisiúin Aontaithe',
#    'gan': '聯合國',
#    'gd': 'Na Dùthchannan Aonaichte',
#    'gl': 'Organización das Nacións Unidas',
#    'gn': 'Tetãnguéra Joaju',
#    'gu': 'સંયુક્ત રાષ્ટ્રસંઘ',
#    'gv': 'Ny h-Ashoonyn Unnaneysit',
#    'ha': 'Majalisar Ɗinkin Duniya',
#    'hak': 'Lièn-ha̍p-koet',
#    'hi': 'संयुक्त राष्ट्र',
#    'hif': 'United Nations',
#    'hr': 'Ujedinjeni narodi',
#    'hsb': 'Zjednoćene narody',
#    'ht': 'ONI',
#    'hu': 'Egyesült Nemzetek Szervezete',
#    'hy': 'Միավորված ազգերի կազմակերպություն',
#    'ia': 'Organisation del Nationes Unite',
#    'id': 'Perserikatan Bangsa-Bangsa',
#    'ie': 'Organisation del Unit Nationes',
#    'ilo': 'Dagiti Nagkaykaysa a Pagilian',
#    'io': 'Unionita Nacioni',
#    'is': 'Sameinuðu þjóðirnar',
#    'it': 'Organizzazione delle Nazioni Unite',
#    'ja': '国際連合',
#    'jam': 'Yunaitid Nieshan',
#    'jbo': 'gunma natmi',
#    'jv': 'Pasarékatan Bangsa-Bangsa',
#    'ka': 'გაერთიანებული ერების ორგანიზაცია',
#    'kaa': "Birlesken Milletler Sho'lkemı",
#    'kab': 'Tuddsa n Yeɣlanen Yeddukklen',
#    'kbd': 'Лъэпкъ Зэгуэтхэр, ЛъЗ',
#    'kk': 'Біріккен Ұлттар Ұйымы',
#    'kl': 'FN',
#    'km': 'អង្គការសហប្រជាជាតិ',
#    'kn': 'ಸಂಯುಕ್ತ ರಾಷ್ಟ್ರ ಸಂಸ್ಥೆ',
#    'ko': '유엔',
#    'krc': 'Бирлешген Миллетлени Организациясы',
#    'ku': 'Neteweyên Yekbûyî',
#    'kv': 'Ӧтувтчӧм Войтыръяслӧн Котыр',
#    'kw': 'Kenedhlow Unys',
#    'ky': 'Бириккен Улуттар Уюму',
#    'la': 'Nationes Unitae',
#    'lad': 'Nasyones Unidas',
#    'lb': 'Vereent Natiounen',
#    'lez': 'Садхьанвай миллетрин тешкилат',
#    'li': 'Verenigde Naties',
#    'lij': "Organizzaçion d'e Naçioin Unïe",
#    'lmo': 'Urganizaziun di Naziun Ünii',
#    'ln': 'Lisangá lya Bikólo bya Molɔ́ngɔ́',
#    'lo': 'ສະຫະປະຊາຊາດ',
#    'lt': 'Jungtinių Tautų Organizacija',
#    'lv': 'Apvienoto Nāciju Organizācija',
#    'mai': 'संयुक्त राष्ट्र सङ्घ',
#    'map-bms': 'Perserikatan Bangsa-Bangsa',
#    'mg': 'Firenena Mikambana',
#    'mhr': 'Иктыш ушнышо Наций-влак Организаций',
#    'min': 'Pasarikatan Banso-Banso',
#    'mk': 'Обединети нации',
#    'ml': 'ഐക്യരാഷ്ട്രസഭ',
#    'mn': 'Нэгдсэн Үндэстний Байгууллага',
#    'mr': 'संयुक्त राष्ट्रे',
#    'ms': 'Pertubuhan Bangsa-Bangsa Bersatu',
#    'mt': 'Ġnus Magħquda',
#    'mwl': 'Naciones Ounidas',
#    'my': 'ကုလသမဂ္ဂ',
#    'mzn': 'متحد ملل سازمان',
#    'nah': 'Tlacetililli Tlacatiyan',
#    'nap': 'Organizzazione d"e Nazzione Aunite',
#    'nds': 'Vereente Natschonen',
#    'ne': 'संयुक्त राष्ट्र संघ',
#    'new': 'संयुक्त राष्ट्र संघ',
#    'nl': 'Verenigde Naties',
#    'nn': 'Dei sameinte nasjonane',
#    'no': 'De forente nasjoner',
#    'nov': 'Unionati Nationes',
#    'nv': 'Nahasdzáán Bikáaʼgi Kéyah Naaznilgo Ałhidadiidzooígíí',
#    'oc': 'Organizacion de las Nacions Unidas',
#    'or': 'ମିଳିତ ଜାତିସଂଘ',
#    'os': 'Иугонд Нациты Организаци',
#    'pa': 'ਸੰਯੁਕਤ ਰਾਸ਼ਟਰ',
#    'pam': 'Misasanmetung a Bangsa',
#    'pap': 'Nashonan Uni',
#    'pfl': 'Verainde Nadsione',
#    'pl': 'Organizacja Narodów Zjednoczonych',
#    'pms': 'Organisassion dle Nassion Unìe',
#    'pnb': 'اقوام متحدہ',
#    'ps': 'ملگري ملتونه',
#    'pt': 'Organização das Nações Unidas',
#    'qu': 'Huñusqa Aylluskakuna',
#    'rm': 'Organisaziun da las Naziuns unidas',
#    'ro': 'Organizația Națiunilor Unite',
#    'roa-rup': 'Natsiile Unite',
#    'ru': 'Организация Объединённых Наций',
#    'rue': 'Орґанізація Зъєдиненых Націй',
#    'rw': 'Umuryango w’Abibumye',
#    'sa': 'संयुक्तराष्ट्रसङ्घः',
#    'sah': 'Холбоһуктаах Нациялар Тэрилтэлэрэ',
#    'sc': 'ONU',
#    'scn': 'Nazziuni Uniti',
#    'sco': 'Unitit Naitions',
#    'sd': 'گڏيل قومون',
#    'se': 'Ovttastuvvan našuvnnat',
#    'sh': 'Ujedinjene nacije',
#    'si': 'එක්සත් ජාතීන්ගේ සංවිධානය',
#    'simple': 'United Nations',
#    'sk': 'Organizácia Spojených národov',
#    'sl': 'Organizacija združenih narodov',
#    'sm': 'Malo Aufaatasi',
#    'sn': 'Mubatanidzwa weNyika Pasirose',
#    'so': 'Qaramada Midoobay',
#    'sq': 'Organizata e Kombeve të Bashkuara',
#    'sr': 'Организација уједињених нација',
#    'ss': 'Mhlabuhlangene',
#    'stq': 'Fereende Natione',
#    'su': 'Perserikatan Bangsa-Bangsa',
#    'sv': 'Förenta nationerna',
#    'sw': 'Umoja wa Mataifa',
#    'ta': 'ஐக்கிய நாடுகள் அவை',
#    'te': 'ఐక్యరాజ్య సమితి',
# ...
#    'pl': 'Adli Mansur',
#    'pt': 'Adly Mansur',
#    'ro': 'Adli Mansour',
#    'ru': 'Мансур, Адли',
#    'sco': 'Adly Mansour',
#    'simple': 'Adly Mansour',
#    'sr': 'Адли Мансур',
#    'sv': 'Adli Mansour',
#    'tr': 'Adli Mansur',
#    'tt': 'Гадли Мансур',
#    'uk': 'Адлі Мансур',
#    'vi': 'Adly Mansour',
#    'zh': '阿德利·曼苏尔'},
#   'ערב הסעודית': {'ace': 'Arab Saudi',
#    'ady': 'Сауд Арабие',
#    'af': 'Saoedi-Arabië',
#    'als': 'Saudi-Arabien',
#    'am': 'ሳዑዲ አረቢያ',
#    'an': 'Arabia Saudí',
#    'ang': 'Saudisc Arabea',
#    'ar': 'السعودية',
#    'arc': 'ܣܥܘܕܝܐ',
#    'arz': 'المملكه العربيه السعوديه',
#    'as': 'চৌদি আৰৱ',
#    'ast': 'Arabia Saudita',
#    'av': 'СагІудиязул ГІарабия',
#    'az': 'Səudiyyə Ərəbistanı',
#    'azb': 'عربیستان',
#    'ba': 'Сәғүд Ғәрәбстаны',
#    'bar': 'Saudi Arabien',
#    'bat-smg': 'Sauda Arabėjė',
#    'bcl': 'Arabya Saudita',
#    'be': 'Саудаўская Аравія',
#    'be-x-old': 'Саудаўская Арабія',
#    'bg': 'Саудитска Арабия',
#    'bh': 'सउदी अरब',
#    'bm': 'Saudia Arabu ka Faamamara',
#    'bn': 'সৌদি আরব',
#    'bo': 'སའུ་དི་ཨ་ར་པི་ཡ།',
#    'bpy': 'সৌদি আরব',
#    'br': 'Arabia Saoudat',
#    'bs': 'Saudijska Arabija',
#    'bug': 'Arab Saudi',
#    'bxr': 'Саудай Араб',
#    'ca': 'Aràbia Saudita',
#    'cdo': 'Saudi Ā-lá-báik',
#    'ce': 'СаӀудийн Ӏаьрбийчоь',
#    'ceb': 'Arabyang Saudita',
#    'chr': 'ᏌᎤᏗ ᎡᎴᏈᎠ',
#    'ckb': 'عەرەبستانی سعوودی',
#    'crh': 'Saudiy Arabistan',
#    'cs': 'Saúdská Arábie',
#    'csb': 'Saudëjskô Arabijô',
#    'cv': 'Сауд Аравийĕ',
#    'cy': 'Sawdi Arabia',
#    'da': 'Saudi-Arabien',
#    'de': 'Saudi-Arabien',
#    'diq': 'Erebıstanê Seudi',
#    'dsb': 'Saudi-Arabska',
#    'dv': 'ސައޫދީ އަރަބިއްޔާ',
#    'dz': 'སའུ་དི་ཨེ་ར་སྦི་ཡ་',
#    'el': 'Σαουδική Αραβία',
#    'en': 'Saudi Arabia',
#    'eo': 'Sauda Arabio',
#    'es': 'Arabia Saudita',
#    'et': 'Saudi Araabia',
#    'eu': 'Saudi Arabia',
#    'ext': 'Arabia Saudita',
#    'fa': 'عربستان سعودی',
#    'fi': 'Saudi-Arabia',
#    'fiu-vro': 'Saudi Araabia',
#    'fo': 'Saudiarabia',
#    'fr': 'Arabie saoudite',
#    'frp': 'Arabie saoudita',
#    'frr': 'Saudi-Araabien',
#    'fy': 'Saûdy-Araabje',
#    'ga': 'An Araib Shádach',
#    'gag': 'Saudi Arabiya',
#    'gan': '沙特阿拉伯',
#    'gd': 'Aràibia nan Sabhd',
#    'gl': 'Arabia Saudita',
#    'gn': 'Aravia Saudíta',
#    'gom': 'सौदी अरेबिया',
#    'gu': 'સાઉદી અરેબિયા',
#    'gv': 'Yn Araab Saudi',
#    'ha': 'Saudiyya',
#    'hak': 'Saudi Â-lâ-pak',
#    'haw': 'Saudi ʻAlapia',
#    'hi': 'सउदी अरब',
#    'hif': 'Saudi Arabia',
#    'hr': 'Saudijska Arabija',
#    'hsb': 'Sawdi-Arabska',
#    'ht': 'Arabi Sawoudit',
#    'hu': 'Szaúd-Arábia',
#    'hy': 'Սաուդյան Արաբիա',
#    'ia': 'Arabia Saudita',
#    'id': 'Arab Saudi',
#    'ie': 'Saudi Arabia',
#    'ilo': 'Saudi Arabia',
#    'io': 'Saudi-Arabia',
#    'is': 'Sádí-Arabía',
#    'it': 'Arabia Saudita',
#    'ja': 'サウジアラビア',
#    'jam': 'Saadi Ariebia',
#    'jbo': "djogu'e",
#    'jv': 'Arab Saudi',
#    'ka': 'საუდის არაბეთი',
#    'kaa': 'Saudiya Arabıstanı',
#    'kab': 'Tagelda Tasaɛudit',
#    'kbd': 'Сауд Хьэрыпей',
#    'kg': 'Saudi Arabia',
#    'ki': 'Saudi Arabia',
#    'kk': 'Сауд Арабиясы',
#    'kl': 'Saudi Arabia',
#    'km': 'អារ៉ាប៊ីសាអូឌីត',
#    'kn': 'ಸೌದಿ ಅರೆಬಿಯ',
#    'ko': '사우디아라비아',
#    'krc': 'Сауд Арабия',
#    'ku': 'Erebistana Siyûdî',
#    'kv': 'Саудса Аравия',
#    'kw': 'Arabi Saoudek',
#    'ky': 'Сауд Арaбиясы',
#    'la': 'Arabia Saudiana',
#    'lad': 'Arabia Saudita',
#    'lb': 'Saudi-Arabien',
#    'lbe': 'Саоьдуллал Аьрабусттан',
#    'lez': 'Сауди Арабистан',
#    'li': 'Saoedi-Arabië',
#    'lij': 'Arabia Saudïa',
#    'lmo': 'Arabia Saudita',
#    'ln': 'Saudi Arabia',
#    'lrc': 'عأرأڤئستان سوعوٙدی',
#    'lt': 'Saudo Arabija',
#    'lv': 'Saūda Arābija',
#    'mg': 'Arabia Saodita',
#    'min': 'Arab Saudi',
#    'mk': 'Саудиска Арабија',
#    'ml': 'സൗദി അറേബ്യ',
#    'mn': 'Саудын Араб',
#    'mr': 'सौदी अरेबिया',
#    'ms': 'Arab Saudi',
#    'mt': 'Arabja Sawdija',
#    'my': 'ဆော်ဒီအာရေဗျနိုင်ငံ',
#    'mzn': 'عربستون',
#    'na': 'Taudiarabiya',
#    'nah': 'Saudarabia',
#    'nds': 'Saudi-Arabien',
#    'ne': 'साउदी अरब',
#    'nl': 'Saoedi-Arabië',
#    'nn': 'Saudi-Arabia',
#    'no': 'Saudi-Arabia',
#    'nov': 'Saudi Arabia',
#    'nrm': 'Arabie Saudi',
#    'nv': 'Ásáí Bikéyah Saʼoodí',
#    'oc': 'Arabia Saudita',
#    'olo': 'Saudi Arabii',
#    'om': "Sa'ud Arabiyaa",
#    'or': 'ସାଉଦି ଆରବ',
#    'os': 'Сауды Арави',
#    'pa': 'ਸਾਊਦੀ ਅਰਬ',
#    'pam': 'Saudita Arabia',
#    'pap': 'Saudi Arabia',
#    'pcd': 'Arabie saoudite',
#    'pdc': 'Saudi Arabia',
#    'pi': 'सऊदी अरब',
#    'pih': 'Saudi Arabia',
#    'pl': 'Arabia Saudyjska',
#    'pms': 'Arabia Saodita',
#    'pnb': 'سعودی عرب',
#    'ps': 'سعودي عربستان',
#    'pt': 'Arábia Saudita',
#    'qu': 'Sawud Arabya',
#    'rm': 'Arabia Saudita',
#    'ro': 'Arabia Saudită',
#    'roa-rup': 'Arabia Saudescã',
#    'roa-tara': 'Arabie Saudite',
#    'ru': 'Саудовская Аравия',
#    'rue': 'Саудьска Арабія',
#    'rw': 'Arabiya Sawudite',
#    'sa': 'सऊदी अरब',
#    'sah': 'Сауд Арабията',
#    'scn': 'Arabbia Saudita',
#    'sco': 'Saudi Arabie',
#    'sd': 'سعودي عرب',
#    'se': 'Saudi-Arábia',
#    'sh': 'Saudijska Arabija',
#    'si': 'සවුදි අරාබියාව',
#    'simple': 'Saudi Arabia',
#    'sk': 'Saudská Arábia',
#    'sl': 'Saudova Arabija',
#    'sn': 'Saudi Arabia',
#    'so': 'Sacuudi Carabiya',
#    'sq': 'Arabia Saudite',
#    'sr': 'Саудијска Арабија',
#    'ss': 'I-Arabhiya',
#    'su': 'Saudi Arabia',
#    'sv': 'Saudiarabien',
#    'sw': 'Saudia',
#    'szl': 'Saudyjsko Arabijo',
#    'ta': 'சவூதி அரேபியா',
#    'te': 'సౌదీ అరేబియా',
#    'tet': 'Arábia Saudita',
#    'tg': 'Арабистони Саудӣ',
#    'th': 'ประเทศซาอุดีอาระเบีย',
#    'tk': 'Saud Arabystany',
#    'tl': 'Saudi Arabia',
#    'tpi': 'Saudi Arabia',
#    'tr': 'Suudi Arabistan',
#    'tt': 'Согуд Гарәбстаны',
#    'tum': 'Saudi Arabia',
#    'udm': 'Сауд Аравия',
#    'ug': 'سەئۇدى ئەرەبىستان',
#    'uk': 'Саудівська Аравія',
#    'ur': 'سعودی عرب',
#    'uz': 'Saudiya Arabistoni',
#    'vec': 'Arabia Saudìa',
#    'vep': 'Saudan Arabii',
#    'vi': 'Ả Rập Saudi',
#    'vo': 'Sauda-Larabän',
#    'war': 'Arabya Saudita',
#    'wo': 'Araabi Sawdit',
#    'wuu': '沙特阿拉伯',
#    'xal': 'Саудин Араб Нутг',
#    'xmf': 'საუდიშ არაბეთი',
#    'yi': 'סאודי אראביע',
#    'yo': 'Sáúdí Arábíà',
#    'za': 'Saudi Ahlazbwz',
#    'zea': 'Saoedi-Araobië',
#    'zh': '沙特阿拉伯',
#    'zh-classical': '沙特阿拉伯',
#    'zh-min-nan': 'Saudi A-la-pek',
#    'zh-yue': '沙地阿拉伯'},
#   'פלסטינים': {'an': 'Palestins',
#    'ar': 'فلسطينيون',
#    'az': 'Fələstinli',
#    'be': 'Палесцінцы',
#    'be-x-old': 'Палестынцы',
#    'bg': 'Палестинци',
#    'cs': 'Palestinci',
#    'cy': 'Palesteiniaid',
#    'da': 'Det palæstinensiske folk',
#    'de': 'Palästinenser',
#    'el': 'Παλαιστίνιοι',
#    'en': 'Palestinians',
#    'eo': 'Palestinanoj',
#    'es': 'Pueblo palestino',
#    'fa': 'مردم فلسطینی',
#    'fi': 'Palestiinalaiset',
#    'fr': 'Palestiniens',
#    'hr': 'Palestinci',
#    'id': 'Bangsa Palestina',
#    'it': 'Palestinesi',
#    'ja': 'パレスチナ人',
#    'ka': 'პალესტინელები',
#    'ko': '팔레스타인인',
#    'la': 'Palaestini',
#    'lt': 'Palestiniečiai',
#    'lv': 'Palestīnieši',
#    'ms': 'Orang Palestin',
#    'nl': 'Palestijnen',
#    'nn': 'Palestinarar',
#    'no': 'Det palestinske folk',
#    'pl': 'Palestyńczycy',
#    'pt': 'Palestinos',
#    'ru': 'Палестинцы',
#    'sc': 'Palestinesos',
#    'sh': 'Palestinci',
#    'simple': 'Palestinian people',
#    'sl': 'Palestinci',
#    'sr': 'Палестинци',
#    'sv': 'Palestinier',
#    'tl': 'Mga Palestino',
#    'tr': 'Filistinliler',
#    'uk': 'Палестинці',
#    'yi': 'פאלעסטינער',
#    'zh': '巴勒斯坦人'},
#   'צבא מצרים': {'ar': 'القوات البرية المصرية',
#    'arz': 'القوات البريه المصريه',
#    'de': 'Ägyptisches Heer',
#    'en': 'Egyptian Army',
#    'fa': 'نیروی زمینی مصر',
#    'fr': 'Armée de terre égyptienne',
#    'it': 'Esercito egiziano',
#    'ko': '이집트 육군',
#    'ms': 'Tentera Darat Mesir',
#    'nl': 'Landmacht van Egypte',
#    'pt': 'Exército Egípcio',
#    'ru': 'Сухопутные войска Египта',
#    'ur': 'مصری فوج'},
#   'קהיר': {'ace': 'Al-Qahirah',
#    'ady': 'Каир',
#    'af': 'Kaïro',
#    'ak': 'Cairo',
#    'als': 'Kairo',
#    'am': 'ካይሮ',
#    'an': 'O Caire',
#    'ar': 'القاهرة',
#    'arz': 'القاهره',
#    'ast': 'El Cairo',
#    'av': 'Каир',
#    'az': 'Qahirə',
#    'azb': 'قاهیره',
#    'ba': 'Ҡаһирә',
#    'bat-smg': 'Kairs',
#    'bcl': 'Cairo',
#    'be': 'Горад Каір',
#    'be-x-old': 'Каір',
#    'bg': 'Кайро',
#    'bh': 'काहिरा',
#    'bn': 'কায়রো',
#    'bo': 'ཁ་ཡི་རོ',
#    'br': 'Kaero',
#    'bs': 'Kairo',
#    'bxr': 'Каир',
#    'ca': 'El Caire',
#    'cdo': 'Cairo',
#    'ce': 'КъахӀира',
#    'ceb': 'Cairo',
#    'ckb': 'قاھیرە',
#    'crh': 'Qaire',
#    'cs': 'Káhira',
#    'csb': 'Kairo',
#    'cv': 'Каир',
#    'cy': 'Cairo',
#    'da': 'Kairo',
#    'de': 'Kairo',
#    'diq': 'Qahira',
#    'dsb': 'Kairo',
#    'el': 'Κάιρο',
#    'en': 'Cairo',
#    'eo': 'Kairo',
#    'es': 'El Cairo',
#    'et': 'Kairo',
#    'eu': 'Kairo',
#    'ext': 'El Cairu',
#    'fa': 'قاهره',
#    'fi': 'Kairo',
#    'fiu-vro': 'Kairo',
#    'fo': 'Keiro',
#    'fr': 'Le Caire',
#    'frp': 'Lo Cayiro',
#    'frr': 'Kairo',
#    'fy': 'Kairo',
#    'ga': 'Caireo',
#    'gd': 'Cairo',
#    'gl': 'O Cairo',
#    'gv': 'Cairo',
#    'hak': 'Cairo',
#    'hi': 'काहिरा',
#    'hif': 'Cairo',
#    'hr': 'Kairo',
#    'hsb': 'Kairo',
#    'ht': 'Li Kè',
#    'hu': 'Kairó',
#    'hy': 'Կահիրե',
#    'id': 'Kairo',
#    'ie': 'Cairo',
#    'ilo': 'Cairo',
#    'io': 'Kairo',
#    'is': 'Kaíró',
#    'it': 'Il Cairo',
#    'ja': 'カイロ',
#    'jv': 'Kairo',
#    'ka': 'კაირო',
#    'kaa': 'Al-Qahira',
#    'kab': 'Taqahirt',
#    'ki': 'Cairo',
#    'kk': 'Каир',
#    'kl': 'Cairo',
#    'kn': 'ಕೈರೋ',
#    'ko': '카이로',
#    'ku': 'Qahîre',
#    'kv': 'Каир',
#    'kw': 'Cairo',
#    'ky': 'Каир',
#    'la': 'Cairus',
#    'lad': 'El Kairo',
#    'lb': 'Kairo',
#    'lbe': 'Кьагьира',
#    'lez': 'Каир',
#    'li': 'Caïro',
#    'lij': 'O Cairo',
#    'lmo': 'El Cairo',
#    'ln': 'Kairo',
#    'lrc': 'قاهره',
#    'lt': 'Kairas',
#    'lv': 'Kaira',
#    'mdf': 'Каир',
#    'mg': 'Kairo',
#    'mhr': 'Каир',
#    'min': 'Kairo',
#    'mk': 'Каиро',
#    'ml': 'കെയ്റോ',
#    'mn': 'Каир',
#    'mr': 'कैरो',
#    'mrj': 'Каир',
#    'ms': 'Kaherah',
#    'mwl': 'Cairo',
#    'my': 'ကိုင်ရိုမြို့',
#    'mzn': 'قاهره',
#    'na': 'Cairo',
#    'nah': 'In Cairo',
#    'nap': "'O Cairo",
#    'new': 'कायरो',
#    'nl': 'Caïro (stad)',
#    'nn': 'Kairo',
#    'no': 'Kairo',
#    'ny': 'Cairo',
#    'oc': 'Lo Caire',
#    'olo': 'Kairo',
#    'os': 'Каир',
#    'pa': 'ਕਾਹਿਰਾ',
#    'pap': 'Kairo',
#    'pl': 'Kair',
#    'pms': 'Ël Càiro',
#    'pnb': 'قاہرہ',
#    'pnt': 'Κάιρον',
#    'ps': 'قاهره',
#    'pt': 'Cairo',
#    'qu': 'Qahira',
#    'rm': 'Cairo',
#    'ro': 'Cairo',
#    'roa-tara': "'U Cairo",
#    'ru': 'Каир',
#    'rue': 'Кагіра',
#    'sah': 'Каир',
#    'sc': 'Cairo',
#    'scn': 'Cairu',
#    'sco': 'Cairo',
#    'se': 'Kairo',
#    'sh': 'Kairo',
#    'simple': 'Cairo',
#    'sk': 'Káhira',
#    'sl': 'Kairo',
#    'sn': 'Cairo',
#    'so': 'Qaahiro',
#    'sq': 'Kajro',
#    'sr': 'Каиро',
#    'su': 'Kairo',
#    'sv': 'Kairo',
#    'sw': 'Kairo',
#    'szl': 'Kajir',
#    'ta': 'கெய்ரோ',
#    'te': 'కైరో',
#    'tg': 'Қоҳира',
#    'th': 'ไคโร',
#    'tk': 'Kair',
#    'tl': 'Cairo',
#    'tpi': 'Kairo',
#    'tr': 'Kahire',
#    'tt': 'Каһирә',
#    'tw': 'Kairo',
#    'udm': 'Каир',
#    'ug': 'كايرو',
#    'uk': 'Каїр',
#    'ur': 'قاہرہ',
#    'uz': 'Qohira',
#    'vec': 'El Cairo',
#    'vep': 'Kair',
#    'vi': 'Cairo',
#    'vls': 'Caïro',
#    'vo': 'Kahirä',
#    'wa': 'El Caire',
#    'war': 'Cairo',
#    'wo': 'Xayra',
#    'wuu': '开罗',
#    'xal': 'Каир балһсн',
#    'xmf': 'კაირო',
#    'yi': 'קיירא',
#    'yo': 'Káírò',
#    'zea': 'Caïro (stad)',
#    'zh': '开罗',
#    'zh-min-nan': 'Cairo',
#    'zh-yue': '開羅'},
#   'ראש ממשלת טורקיה': {'ar': 'رئيس وزراء تركيا',
#    'av': 'Турциялъул премьер-министр',
#    'ca': 'Primer Ministre de Turquia',
#    'da': 'Tyrkiets premierministre',
#    'de': 'Ministerpräsidentenamt der Türkei',
#    'el': 'Πρωθυπουργός της Τουρκίας',
#    'en': 'Prime Minister of Turkey',
#    'es': 'Primer ministro de Turquía',
#    'fa': 'نخست\u200cوزیر ترکیه',
#    'fr': 'Premier ministre (Turquie)',
#    'gl': 'Primeiro ministro de Turquía',
#    'jv': 'Perdhana Mentri Turki',
#    'ka': 'თურქეთის პრემიერ-მინისტრი',
#    'ms': 'Perdana Menteri Turki',
#    'nl': 'Premier van Turkije',
#    'pl': 'Premierzy Turcji',
#    'ru': 'Премьер-министр Турции',
#    'tr': 'Türkiye başbakanı',
#    'uk': "Прем'єр-міністр Туреччини",
#    'ur': 'وزیر اعظم ترکی',
#    'uz': 'Turkiya bosh vaziri'},
#   "רג'פ טאיפ ארדואן": {'ady': 'Рэджэб Эрдоган',
#    'af': 'Recep Tayyip Erdoğan',
#    'als': 'Recep Tayyip Erdoğan',
#    'ar': 'رجب طيب أردوغان',
#    'arz': 'رجب طيب اردوغان',
#    'av': 'Эрдогъан, Ражаб ТІайип',
#    'az': 'Rəcəb Tayyib Ərdoğan',
#    'azb': 'رجب طیب اردوغان',
#    'ba': 'Реджеп Тайип Эрдоған',
#    'bcl': 'Recep Tayyip Erdoğan',
#    'be': 'Рэджэп Таіп Эрдаган',
#    'be-x-old': 'Рэджэп Таіп Эрдаган',
#    'bg': 'Реджеп Таип Ердоган',
#    'bn': 'রিসেপ তায়িপ এরদোয়ান',
#    'br': 'Recep Tayyip Erdoğan',
#    'bs': 'Recep Tayyip Erdoğan',
#    'ca': 'Recep Tayyip Erdoğan',
#    'ce': 'Эрдоган, Реджеп Тайип',
#    'ckb': 'ڕەجەب تەییب ئەردۆغان',
#    'crh': 'Recep Tayyip Erdoğan',
#    'cs': 'Recep Tayyip Erdoğan',
#    'cv': 'Реджеп Тайип Эрдоган',
#    'cy': 'Recep Tayyip Erdoğan',
#    'da': 'Recep Tayyip Erdoğan',
#    'de': 'Recep Tayyip Erdoğan',
#    'diq': 'Recep Tayyip Erdoğan',
#    'el': 'Ρετζέπ Ταγίπ Ερντογάν',
#    'en': 'Recep Tayyip Erdoğan',
#    'eo': 'Recep Tayyip Erdoğan',
#    'es': 'Recep Tayyip Erdoğan',
#    'et': 'Recep Tayyip Erdoğan',
#    'eu': 'Recep Tayyip Erdoğan',
#    'fa': 'رجب طیب اردوغان',
#    'fi': 'Recep Tayyip Erdoğan',
#    'fr': 'Recep Tayyip Erdoğan',
#    'gl': 'Recep Tayyip Erdoğan',
#    'hi': 'रजब तईब इरदुगान',
#    'hr': 'Recep Tayyip Erdoğan',
#    'hsb': 'Recep Tayyip Erdoğan',
#    'hu': 'Recep Tayyip Erdoğan',
#    'hy': 'Ռեջեփ Թայիփ Էրդողան',
#    'ia': 'Recep Tayyip Erdoğan',
#    'id': 'Recep Tayyip Erdoğan',
#    'ie': 'Recep Tayyip Erdoğan',
#    'io': 'Recep Tayyip Erdoğan',
#    'is': 'Recep Tayyip Erdoğan',
#    'it': 'Recep Tayyip Erdoğan',
#    'ja': 'レジェップ・タイイップ・エルドアン',
#    'ka': 'რეჯეფ თაიფ ერდოღანი',
#    'kk': 'Режеп Тайип Эрдоған',
#    'ko': '레제프 타이이프 에르도안',
#    'ku': 'Recep Tayyip Erdoğan',
#    'ky': 'Режеп Тайип Эрдоган',
#    'la': 'Recep Tayyip Erdoğan',
#    'lad': 'Recep Tayyip Erdoğan',
#    'lb': 'Recep Tayyip Erdoğan',
#    'lbe': 'Эрдогъан, Ражаб ТIайип',
#    'lmo': 'Recep Tayyip Erdoğan',
#    'lo': 'ເລເຈບ ໄຕຢິບ ແອໂດກັນ',
#    'lrc': 'رجب طیب أردوغان',
#    'lv': 'Redžeps Tajjips Erdogans',
#    'mk': 'Реџеп Таип Ердоган',
#    'ml': 'റെജപ് തയ്യിപ്\u200c എർദ്വാൻ',
#    'mr': 'रेसेप तय्यिप एर्दोगान',
#    'ms': 'Recep Tayyip Erdoğan',
#    'mzn': 'رجب طیب اردوغان',
#    'nl': 'Recep Tayyip Erdoğan',
#    'nn': 'Recep Tayyip Erdoğan',
#    'no': 'Recep Tayyip Erdoğan',
#    'oc': 'Recep Tayyip Erdoğan',
#    'pl': 'Recep Tayyip Erdoğan',
#    'ps': 'رجب طيب اردوغان',
#    'pt': 'Recep Tayyip Erdoğan',
#    'qu': 'Recep Tayyip Erdoğan',
#    'ro': 'Recep Tayyip Erdoğan',
#    'ru': 'Эрдоган, Реджеп Тайип',
#    'rw': 'Recep Tayyip Erdoğan',
#    'sah': 'Эрдоган Реджеп Тайип',
#    'sco': 'Recep Tayyip Erdoğan',
#    'sh': 'Recep Tayyip Erdoğan',
#    'simple': 'Recep Tayyip Erdoğan',
#    'sk': 'Recep Tayyip Erdoğan',
#    'sl': 'Recep Tayyip Erdoğan',
#    'so': 'Rajab Dayib Erdogaan',
#    'sq': 'Rexhep Taip Erdoan',
#    'sr': 'Реџеп Тајип Ердоган',
#    'sv': 'Recep Tayyip Erdoğan',
#    'ta': 'ரசிப் தைய்யிப் எர்டோகன்',
#    'tg': 'Раҷаб Тайиб Ардуғон',
#    'th': 'เรเจป ไตยิป แอร์โดอัน',
#    'tk': 'Rejep Taýýyp Ärdogan',
#    'tl': 'Recep Tayyip Erdoğan',
#    'tr': 'Recep Tayyip Erdoğan',
#    'tt': 'Рәҗәп Таййип Әрдоган',
#    'ug': 'رەجەپ تاييىپ ئەردوغان',
#    'uk': 'Реджеп Таїп Ердоган',
#    'ur': 'رجب طیب اردوغان',
#    'uz': 'Recep Tayyip Erdoğan',
#    'vi': 'Recep Tayyip Erdoğan',
#    'wuu': '雷吉泼·泰伊泼·埃尔多安',
#    'yo': 'Recep Tayyip Erdoğan',
#    'zh': '雷杰普·塔伊普·埃尔多安',
#    'zh-min-nan': 'Recep Tayyip Erdoğan',
#    'zh-yue': '利脊·泰業·埃爾多安'},
#   'תנועת הנוער של ה-6 באפריל': {'ar': 'حركة شباب 6 أبريل',
#    'arz': 'حركة شباب 6 ابريل',
#    'az': '“6 aprel” Hərəkatı',
#    'de': 'Jugendbewegung des 6. April',
#    'en': 'April 6 Youth Movement',
#    'fa': 'جنبش ۶ آوریل',
#    'fi': 'Huhtikuun 6. päivän nuorisoliike',
#    'fr': 'Mouvement de la jeunesse du 6 avril',
#    'ja': '4月6日運動',
#    'ko': '4월 6일 청년 운동',
#    'ml': 'ഏപ്രിൽ 6 യുവജനപ്രസ്ഥാനം',
#    'nl': '6 aprilbeweging',
#    'pt': 'Movimento Jovem 6 de Abril',
#    'ru': 'Движение 6 апреля',
#    'sv': 'Sjätte april-rörelsen',
#    'uk': 'Молодіжний рух 6 квітня',
#    'zh': '4月6日青年运动'}})

# %%
len_transoutlink_dict_counterEn = {}

for lang,titles_dict in translation_dict.items():
    len_transoutlink_dict_counterEn[lang]=0         #starting at fa at a count of 0 
    for art_title,lang_dict in titles_dict.items(): #go into links on fa 
        if 'en' in lang_dict.keys():               #check for en version in links 
            len_transoutlink_dict_counterEn[lang] +=1   #if one is found add to counter

# %%
len_transoutlink_dict_enList = {}

for lang,titles_dict in translation_dict.items():
    len_transoutlink_dict_enList[lang]=[]         #starting at fa at a count of 0 
    for art_title,lang_dict in titles_dict.items(): #go into links on fa 
        if 'en' in lang_dict.keys():  
            _title = lang_dict['en']        #check for en version in links 
            len_transoutlink_dict_enList[lang].append(_title)

# %%
len_transoutlink_dict = {}

for langlinks_lang,titles in translation_dict.items():
    len_transoutlink_dict[langlinks_lang] = len(titles)

# %%
s_d2 = pd.Series(titles_and_lang_dict)

s_d1 = pd.Series(_langAbrev_dict)

s_d3 = pd.Series(len_transoutlink_dict)

s_d4 = pd.Series(len_transoutlink_dict_counterEn)

# %%
df_mix = pd.DataFrame({'lang' : s_d1,
                       'title' : s_d2, 
                       'total links' : s_d3,
                       'english links': s_d4})

df_mix = df_mix[['lang', 'title', 'total links', 'english links']]

# %%
df_mix['percent en linkbacks'] = df_mix['english links']/df_mix['total links']

df_mix
# Out:
#                 lang                                       title  total links  \
# af         Afrikaans              Egiptiese staatsgreep van 2013            4
# ar            Arabic                          انقلاب 2013 في مصر          110
# arz  Egyptian Arabic                        خريطة المستقبل (مصر)           28
# az       Azerbaijani              Misirdə hərbi çeviriliş (2013)            0
# bg         Bulgarian         Държавен преврат в Египет (2013 г.)           24
# ca           Catalan             Cop d'Estat a Egipte l'any 2013           21
# ckb  Central Kurdish                          کودەتای ٢٠١٣ی میسر           11
# de            German               Militärputsch in Ägypten 2013          267
# el             Greek                 Αιγυπτιακό πραξικόπημα 2013            9
# en         2013年埃及政变                   2013 Egyptian coup d'état          262
# es           Spanish           Golpe de Estado en Egipto de 2013           69
# fa           Persian                             کودتای ۲۰۱۳ مصر           32
# fi           Finnish                 Egyptin vallankaappaus 2013           14
# fr            French     Coup d'État du 3 juillet 2013 en Égypte           87
# he            Hebrew                        ההפיכה במצרים (2013)           48
# hi             Hindi               मिस्र में सैन्य तख्तापलट २०१३            3
# id        Indonesian                           Kudeta Mesir 2013            8
# it           Italian                     Golpe egiziano del 2013           57
# ja          Japanese                              2013年エジプトクーデター          235
# ko            Korean                               2013년 이집트 쿠데타            9
# nl             Dutch  Protesten en staatsgreep in Egypte in 2013           22
# pl            Polish               Zamach stanu w Egipcie (2013)           17
# pt        Portuguese            Golpe de Estado no Egito em 2013           26
# ro          Romanian         Lovitura de stat din Egipt din 2013           29
# ru           Russian           Военный переворот в Египте (2013)           33
# sr           Serbian                Државни удар у Египту (2013)           28
# tg             Tajik                           Кудатои 2013 Миср            7
# tr           Turkish                   2013 Mısır askerî darbesi           39
# uk         Ukrainian          Військовий переворот в Єгипті 2013           34
# ur              Urdu                        2013ء مصری فوجی تاخت            2
# vi        Vietnamese                       Đảo chính Ai Cập 2013           45
# zh           Chinese                                   2013年埃及政变           91
#
#      english links  percent en linkbacks
# af               2              0.500000
# ar              94              0.854545
# arz             26              0.928571
# az               0                   NaN
# bg              17              0.708333
# ca              21              1.000000
# ckb              9              0.818182
# de             233              0.872659
# el               6              0.666667
# en               0              0.000000
# es              65              0.942029
# fa              30              0.937500
# fi              10              0.714286
# fr              74              0.850575
# he              45              0.937500
# hi               3              1.000000
# id               8              1.000000
# it              50              0.877193
# ja             221              0.940426
# ko               9              1.000000
# nl              22              1.000000
# pl              17              1.000000
# pt              23              0.884615
# ro              19              0.655172
# ru              33              1.000000
# sr              24              0.857143
# tg               4              0.571429
# tr              27              0.692308
# uk              32              0.941176
# ur               2              1.000000
# vi              34              0.755556
# zh              78              0.857143
